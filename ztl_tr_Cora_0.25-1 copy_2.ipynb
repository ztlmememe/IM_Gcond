# %%
from deeprobust.graph.data import Dataset
import numpy as np
import random
import time
import argparse
import torch
from utils import *
import torch.nn.functional as F
# watch -n 1 nvidia-smi
from utils_graphsaint import DataGraphSAINT
# 3,5,6 --nlayers=2 --sgc=1 --lr_feat=1e-4 --gpu_id=0  --lr_adj=1e-4 --r=${r}  --seed=1 --epoch=600 --save=0
parser = argparse.ArgumentParser()
parser.add_argument('--gpu_id', type=int, default=0, help='gpu id')
parser.add_argument('--dataset', type=str, default='cora')
parser.add_argument('--dis_metric', type=str, default='ours')
parser.add_argument('--epochs', type=int, default=600)
parser.add_argument('--nlayers', type=int, default=2)
parser.add_argument('--hidden', type=int, default=256)
parser.add_argument('--lr_adj', type=float, default=1e-4)
parser.add_argument('--lr_feat', type=float, default=1e-4)
parser.add_argument('--lr_model', type=float, default=0.01)
parser.add_argument('--weight_decay', type=float, default=0.0)
parser.add_argument('--dropout', type=float, default=0.0)
parser.add_argument('--normalize_features', type=bool, default=True)
parser.add_argument('--keep_ratio', type=float, default=1.0)
parser.add_argument('--reduction_rate', type=float, default=0.25)  #######
parser.add_argument('--seed', type=int, default=1, help='Random seed.')
parser.add_argument('--alpha', type=float, default=1, help='regularization term.')
parser.add_argument('--debug', type=int, default=0)
parser.add_argument('--sgc', type=int, default=1)
parser.add_argument('--inner', type=int, default=0)
parser.add_argument('--outer', type=int, default=20)
parser.add_argument('--save', type=int, default=0)
parser.add_argument('--one_step', type=int, default=0)
args = parser.parse_args([])

# import pickle
# with open('D:/pythonProject/python_file/Graph_DD/G-Meta-master/DATA/arxiv/label.pkl', 'rb') as f:
#     info = pickle.load(f)

# %%
torch.cuda.set_device(args.gpu_id)

# random seed setting
random.seed(args.seed)
np.random.seed(args.seed)
torch.manual_seed(args.seed)
torch.cuda.manual_seed(args.seed)

print(args)

data_graphsaint = ['flickr', 'reddit', 'ogbn-arxiv']
if args.dataset in data_graphsaint:
    data = DataGraphSAINT(args.dataset)
    data_full = data.data_full
else:
    data_full = get_dataset(args.dataset, args.normalize_features)
    data = Transd2Ind(data_full, keep_ratio=args.keep_ratio)
# Out:
# Namespace(gpu_id=0, dataset='cora', dis_metric='ours', epochs=600, nlayers=2, hidden=256, lr_adj=0.0001, lr_feat=0.0001, lr_model=0.01, weight_decay=0.0, dropout=0.0, normalize_features=True, keep_ratio=1.0, reduction_rate=0.25, seed=1, alpha=1, debug=0, sgc=1, inner=0, outer=20, save=0, one_step=0)
# size of adj_train: (140, 140)
# #edges in adj_train: 42.0

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn import Parameter
import torch.nn.functional as F
# from utils import match_loss, regularization, row_normalize_tensor
from utils import match_loss, regularization, row_normalize_tensor
import deeprobust.graph.utils as utils
from copy import deepcopy
import numpy as np
from tqdm import tqdm
from models.gcn import GCN
from models.sgc import SGC
from models.sgc_multi import SGC as SGC1
from models.parametrized_adj import PGE
import scipy.sparse as sp
from torch_sparse import SparseTensor
import torch
import torch.nn.functional as F
import logging

class GCond:

    def __init__(self, data, args, device='cuda', **kwargs):
        self.data = data
        self.args = args
        self.device = device

        # n = data.nclass * args.nsamples
        n = int(data.feat_train.shape[0] * args.reduction_rate)
        # from collections import Counter; print(Counter(data.labels_train))

        d = data.feat_train.shape[1]
        self.nnodes_syn = n
        self.feat_syn = nn.Parameter(torch.FloatTensor(n, d).to(device))
        self.pge = PGE(nfeat=d, nnodes=n, device=device,args=args).to(device)

        self.labels_syn = torch.LongTensor(self.generate_labels_syn(data)).to(device)

        self.reset_parameters()
        self.optimizer_feat = torch.optim.Adam([self.feat_syn], lr=args.lr_feat)
        self.optimizer_pge = torch.optim.Adam(self.pge.parameters(), lr=args.lr_adj)
        print('adj_syn:', (n,n), 'feat_syn:', self.feat_syn.shape)
    
    def get_grad_norm_sum(self, model):
        grad_all = []
        grad_norm = 0.0
        for param in model.parameters():
            # grad_all.append(param.grad)
            # grad_all_cat = torch.cat([grad.view(-1) for grad in grad_all])
            # grad_all_abs = torch.abs(grad_all_cat)
            # grad_sum = grad_all_abs.sum()
            grad_norm += param.grad.norm(2).item() ** 2
        grad_norm = grad_norm ** 0.5
        return grad_norm
    
    def get_grad_sum(self, model):
        grad_all = []
        grad_norm = 0.0
        for param in model.parameters():
            grad_all.append(param.grad)
            grad_all_cat = torch.cat([grad.view(-1) for grad in grad_all])
            grad_all_abs = torch.abs(grad_all_cat)
            grad_sum = grad_all_abs.sum()
        return grad_sum
        
    def reset_parameters(self):
        self.feat_syn.data.copy_(torch.randn(self.feat_syn.size()))

    def generate_labels_syn(self, data):
        from collections import Counter
        counter = Counter(data.labels_train)
        num_class_dict = {}
        n = len(data.labels_train)

        sorted_counter = sorted(counter.items(), key=lambda x:x[1])
        sum_ = 0
        labels_syn = []
        self.syn_class_indices = {}
        for ix, (c, num) in enumerate(sorted_counter):
            if ix == len(sorted_counter) - 1:
                num_class_dict[c] = int(n * self.args.reduction_rate) - sum_
                self.syn_class_indices[c] = [len(labels_syn), len(labels_syn) + num_class_dict[c]]
                labels_syn += [c] * num_class_dict[c]
            else:
                num_class_dict[c] = max(int(num * self.args.reduction_rate), 1)
                sum_ += num_class_dict[c]
                self.syn_class_indices[c] = [len(labels_syn), len(labels_syn) + num_class_dict[c]]
                labels_syn += [c] * num_class_dict[c]

        self.num_class_dict = num_class_dict
        return labels_syn


    def test_with_val(self, verbose=True):
        res = []

        data, device = self.data, self.device
        feat_syn, pge, labels_syn = self.feat_syn.detach(), \
                                self.pge, self.labels_syn

        # with_bn = True if args.dataset in ['ogbn-arxiv'] else False
        model = GCN(nfeat=feat_syn.shape[1], nhid=self.args.hidden, dropout=0.5,
                    weight_decay=5e-4, nlayers=2,
                    nclass=data.nclass, device=device).to(device)

        if self.args.dataset in ['ogbn-arxiv']:
            model = GCN(nfeat=feat_syn.shape[1], nhid=self.args.hidden, dropout=0.5,
                        weight_decay=0e-4, nlayers=2, with_bn=False,
                        nclass=data.nclass, device=device).to(device)

        adj_syn = pge.inference(feat_syn)
        args = self.args

        if self.args.save:
            torch.save(adj_syn, f'saved_ours/adj_{args.dataset}_{args.reduction_rate}_{args.seed}.pt')
            torch.save(feat_syn, f'saved_ours/feat_{args.dataset}_{args.reduction_rate}_{args.seed}.pt')

        if self.args.lr_adj == 0:
            n = len(labels_syn)
            adj_syn = torch.zeros((n, n))

        model.fit_with_val(feat_syn, adj_syn, labels_syn, data,
                     train_iters=600, normalize=True, verbose=False)

        model.eval()
        labels_test = torch.LongTensor(data.labels_test).cuda()

        labels_train = torch.LongTensor(data.labels_train).cuda()
        output = model.predict(data.feat_train, data.adj_train)
        loss_train = F.nll_loss(output, labels_train)
        acc_train = utils.accuracy(output, labels_train)
        if verbose:
            print("Train set results:",
                  "loss= {:.4f}".format(loss_train.item()),
                  "accuracy= {:.4f}".format(acc_train.item()))
        res.append(acc_train.item())

        # Full graph
        output = model.predict(data.feat_full, data.adj_full)
        loss_test = F.nll_loss(output[data.idx_test], labels_test)
        acc_test = utils.accuracy(output[data.idx_test], labels_test)
        res.append(acc_test.item())
        if verbose:
            print("Test set results:",
                  "loss= {:.4f}".format(loss_test.item()),
                  "accuracy= {:.4f}".format(acc_test.item()))
        return res

    def train(self, verbose=True):
        
        logger = logging.getLogger(__name__)
        logger.setLevel(logging.INFO)

        # 创建一个文件处理器，并将其添加到 logger 中
        file_handler = logging.FileHandler('gradient_log.txt')
        formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
        file_handler.setFormatter(formatter)
        logger.addHandler(file_handler)
        
        # 创建空列表用于保存每个epoch的LOSS和准确率
        train_loss_values = []
        train_loss_inter_values = []
        train_acc_values = []
        val_loss_values = []
        val_acc_values = []

        args = self.args
        data = self.data
        feat_syn, pge, labels_syn = self.feat_syn, self.pge, self.labels_syn  #初始化数据
        features, adj, labels = data.feat_full, data.adj_full, data.labels_full
        idx_train = data.idx_train

        syn_class_indices = self.syn_class_indices

        features, adj, labels = utils.to_tensor(features, adj, labels, device=self.device)

        feat_sub, adj_sub = self.get_sub_adj_feat(features)
        self.feat_syn.data.copy_(feat_sub)

        if utils.is_sparse_tensor(adj):
            adj_norm = utils.normalize_adj_tensor(adj, sparse=True)
        else:
            adj_norm = utils.normalize_adj_tensor(adj)

        adj = adj_norm
        adj = SparseTensor(row=adj._indices()[0], col=adj._indices()[1],
                value=adj._values(), sparse_sizes=adj.size()).t()


        outer_loop, inner_loop = get_loops(args)
        loss_avg = 0
        # loss_inter_avg = 0

        for it in range(args.epochs+1):
            if args.dataset in ['ogbn-arxiv']:
                model = SGC1(nfeat=feat_syn.shape[1], nhid=self.args.hidden,
                            dropout=0.0, with_bn=False,
                            weight_decay=0e-4, nlayers=2,
                            nclass=data.nclass,
                            device=self.device).to(self.device)
            else:
                if args.sgc == 1:
                    model = SGC(nfeat=data.feat_train.shape[1], nhid=args.hidden,
                                nclass=data.nclass, dropout=args.dropout,
                                nlayers=args.nlayers, with_bn=False,
                                device=self.device).to(self.device)
                else:
                    model = GCN(nfeat=data.feat_train.shape[1], nhid=args.hidden,
                                nclass=data.nclass, dropout=args.dropout, nlayers=args.nlayers,
                                device=self.device).to(self.device)


            model.initialize()

            model_parameters = list(model.parameters())

            optimizer_model = torch.optim.Adam(model_parameters, lr=args.lr_model)
            model.train()
            
            for ol in range(outer_loop):
                adj_syn = pge(self.feat_syn) 
                adj_syn_norm = utils.normalize_adj_tensor(adj_syn, sparse=False)
                feat_syn_norm = feat_syn
                
                BN_flag = False
                for module in model.modules():
                    if 'BatchNorm' in module._get_name(): #BatchNorm
                        BN_flag = True
                if BN_flag:
                    model.train() # for updating the mu, sigma of BatchNorm
                    output_real = model.forward(features, adj_norm)
                    for module in model.modules():
                        if 'BatchNorm' in module._get_name():  #BatchNorm
                            module.eval() # fix mu and sigma of every BatchNorm layer
                            
                loss = torch.tensor(0.0).to(self.device)
                
                for c in range(data.nclass):
                    batch_size, n_id, adjs = data.retrieve_class_sampler(
                            c, adj, transductive=True, args=args)
                    if args.nlayers == 1:
                        adjs = [adjs]

                    adjs = [adj.to(self.device) for adj in adjs]
                    output = model.forward_sampler(features[n_id], adjs)
                    loss_real = F.nll_loss(output, labels[n_id[:batch_size]])

                    gw_real = torch.autograd.grad(loss_real, model_parameters)
                    gw_real = list((_.detach().clone() for _ in gw_real))
                    

                    output_syn = model.forward(feat_syn, adj_syn_norm)

                    ind = syn_class_indices[c]
                    loss_syn = F.nll_loss(
                            output_syn[ind[0]: ind[1]],
                            labels_syn[ind[0]: ind[1]])
                    gw_syn = torch.autograd.grad(loss_syn, model_parameters, create_graph=True)


                    coeff = self.num_class_dict[c] / max(self.num_class_dict.values())
                    loss += coeff  * match_loss(gw_syn, gw_real, args, device=self.device)

#                 print(gw_real_norm/c)
                # gws.append(gw_real_norm/c)
                loss_avg += loss.item()

                # TODO: regularize
                if args.alpha > 0:
                    loss_reg = args.alpha * regularization(adj_syn, utils.tensor2onehot(labels_syn.to("cpu")).to(adj_syn.device))
                else:
                    loss_reg = torch.tensor(0)

                loss = loss + loss_reg
                
                # update sythetic graph
                self.optimizer_feat.zero_grad()
                self.optimizer_pge.zero_grad()
                loss.backward()
                # 迭代一次
                if it % 50 < 10:
                    self.optimizer_pge.step()
                else:
                    self.optimizer_feat.step()

                if args.debug and ol % 5 ==0:
                    print('Gradient matching loss:', loss.item())

                if ol == outer_loop - 1:
                    # print('loss_reg:', loss_reg.item())
                    # print('Gradient matching loss:', loss.item())
                    break

                feat_syn_inner = feat_syn.detach()
                adj_syn_inner = pge.inference(feat_syn_inner)
                adj_syn_inner_norm = utils.normalize_adj_tensor(adj_syn_inner, sparse=False)
                feat_syn_inner_norm = feat_syn_inner
                for j in range(inner_loop):
                    optimizer_model.zero_grad()
                    output_syn_inner = model.forward(feat_syn_inner_norm, adj_syn_inner_norm)
                    loss_syn_inner = F.nll_loss(output_syn_inner, labels_syn)
                    loss_syn_inner.backward()
                    optimizer_model.step() # update gnn param
                    if ol == outer_loop - 2:
                       print('success')
                       grad_sum = self.get_grad_sum(model)
                       res = self.test_with_val()
                       logger.info('outest_epoch #{} inner_epoch#{} grad_sum is {} acc is {}'.format(it, j, grad_sum, res))
                       if j == inner_loop - 1:
                           print('success')
                           optimizer_model = torch.optim.Adam(model_parameters, lr=args.lr_model*8)
                           for i in range(15):
                               optimizer_model.zero_grad()
                               output_syn_inner = model.forward(feat_syn_inner_norm, adj_syn_inner_norm)
                               loss_syn_inner = F.nll_loss(output_syn_inner, labels_syn)
                               loss_syn_inner.backward()
                               optimizer_model.step() # update gnn param
                               grad_sum = self.get_grad_sum(model)
                               res = self.test_with_val()
                               logger.info('outest_epoch #{} inner_epoch#{} new_epoch #{} grad_sum is {} acc is {}'.format(it, j, i, grad_sum, res))
                    # print(loss_syn_inner.item())
                       
            loss_avg /= (data.nclass*outer_loop)

            train_loss_values.append(loss_avg)

            if it % 50 == 0:
                print('Epoch {}, loss_avg: {}'.format(it, loss_avg))

            eval_epochs = [400, 600, 800, 1000, 1200, 1600, 2000, 3000, 4000, 5000]

            if verbose and it in eval_epochs:
            # if verbose and (it+1) % 50 == 0:
                res = []
                runs = 1 if args.dataset in ['ogbn-arxiv'] else 3
                for i in range(runs):
                    if args.dataset in ['ogbn-arxiv']:
                        res.append(self.test_with_val())
                    else:
                        res.append(self.test_with_val())

                res = np.array(res)
                try:
                    train_acc_values.append(res.mean(0)[0])  # 假设train_acc是训练准确率的变量
                    val_acc_values.append(res.mean(0)[1])  # 假设val_loss是验证LOSS的变量
                except:
                    pass
                # 这段代码是在输出训练或测试的平均准确率和标准差,准确率越高越好，标准差越小越好
                print('Train/Test Mean Accuracy:',
                        repr([res.mean(0), res.std(0)]))
                # 输出示例：[array([0.91666667, 0.794 ]), array([0.02357023, 0.0008165 ])]
                # 这个输出表明训练或测试的平均准确率为 0.91666667，标准差为 0.02357023，测试的平均准确率为 0.794，标准差为 0.0008165。
                # 也就是说每个array的0是训练集，1是测试集，第一个array是平均准确率，第二个array是标准差
                
                # repr() 函数是将对象转化为供解释器读取的形式（即字符串形式），它通常用于调试和测试中，方便查看对象的值。

                # res.mean(0) 计算 res 中每一列的平均值，返回一个一维张量，表示平均准确率。res.std(0) 则计算每一列的标准差，也返回一个一维张量，表示准确率的标准差。

                # 最终输出的结果是一个二元组，第一个元素是平均准确率的一维张量，第二个元素是标准差的一维张量，它们都用 repr() 函数转换成字符串形式。
        # 绘制LOSS变化情况的图像
        import matplotlib.pyplot as plt
        plt.figure()
        plt.plot(train_loss_values, label='Train Loss')
        plt.plot(val_loss_values, label='Validation Loss')
        plt.xlabel('Epoch')
        plt.ylabel('Loss')
        plt.legend()
        plt.show()

        # 绘制准确率变化情况的图像
        plt.figure()
        plt.plot(train_acc_values, label='Train Accuracy')
        plt.plot(val_acc_values, label='Validation Accuracy')
        plt.xlabel('Epoch')
        plt.ylabel('Accuracy')
        plt.legend()
        plt.show()
        
    def get_sub_adj_feat(self, features):
        data = self.data
        args = self.args
        idx_selected = []

        from collections import Counter;
        counter = Counter(self.labels_syn.cpu().numpy())

        for c in range(data.nclass):
            tmp = data.retrieve_class(c, num=counter[c])
            tmp = list(tmp)
            idx_selected = idx_selected + tmp
        idx_selected = np.array(idx_selected).reshape(-1)
        features = features[self.data.idx_train][idx_selected]

        # adj_knn = torch.zeros((data.nclass*args.nsamples, data.nclass*args.nsamples)).to(self.device)
        # for i in range(data.nclass):
        #     idx = np.arange(i*args.nsamples, i*args.nsamples+args.nsamples)
        #     adj_knn[np.ix_(idx, idx)] = 1

        from sklearn.metrics.pairwise import cosine_similarity
        # features[features!=0] = 1
        k = 2
        sims = cosine_similarity(features.cpu().numpy())
        sims[(np.arange(len(sims)), np.arange(len(sims)))] = 0
        for i in range(len(sims)):
            indices_argsort = np.argsort(sims[i])
            sims[i, indices_argsort[: -k]] = 0
        adj_knn = torch.FloatTensor(sims).to(self.device)
        return features, adj_knn


def get_loops(args):
    # Get the two hyper-parameters of outer-loop and inner-loop.
    # The following values are empirically good.
    if args.one_step:
        if args.dataset =='ogbn-arxiv':
            return 5, 0
        return 1, 0
    if args.dataset in ['ogbn-arxiv']:
        return args.outer, args.inner
    if args.dataset in ['cora']:
        return 20, 15 # sgc
    if args.dataset in ['citeseer']:
        return 20, 15
    if args.dataset in ['physics']:
        return 20, 10
    else:
        return 20, 10

# %%
# from gcond_transduct_multi_level import GCond
agent = GCond(data, args, device='cuda:0')

agent.train()
# Out:
# adj_syn: (35, 35) feat_syn: torch.Size([35, 1433])
# success
# Train set results: loss= 1.9488 accuracy= 0.1214
# Test set results: loss= 1.9371 accuracy= 0.2670
# success
# Train set results: loss= 1.9459 accuracy= 0.1429
# Test set results: loss= 1.9406 accuracy= 0.2920
# success
# Train set results: loss= 1.9486 accuracy= 0.1286
# Test set results: loss= 1.9350 accuracy= 0.2650
# success
# Train set results: loss= 1.9473 accuracy= 0.1143
# Test set results: loss= 1.9395 accuracy= 0.2890
# success
# Train set results: loss= 1.9468 accuracy= 0.1286
# Test set results: loss= 1.9374 accuracy= 0.2940
# success
# Train set results: loss= 1.9470 accuracy= 0.1357
# Test set results: loss= 1.9397 accuracy= 0.2450
# success
# Train set results: loss= 1.9461 accuracy= 0.1571
# Test set results: loss= 1.9414 accuracy= 0.2980
# success
# Train set results: loss= 1.9469 accuracy= 0.1643
# Test set results: loss= 1.9408 accuracy= 0.2790
# success
# Train set results: loss= 1.9481 accuracy= 0.2357
# Test set results: loss= 1.9386 accuracy= 0.2690
# success
# Train set results: loss= 1.9476 accuracy= 0.1071
# Test set results: loss= 1.9397 accuracy= 0.2780
# success
# Train set results: loss= 1.9461 accuracy= 0.1500
# Test set results: loss= 1.9401 accuracy= 0.3100
# success
# Train set results: loss= 1.9483 accuracy= 0.1643
# Test set results: loss= 1.9430 accuracy= 0.2650
# success
# Train set results: loss= 1.9459 accuracy= 0.1429
# Test set results: loss= 1.9391 accuracy= 0.2510
# success
# Train set results: loss= 1.9473 accuracy= 0.2214
# Test set results: loss= 1.9403 accuracy= 0.2900
# success
# Train set results: loss= 1.9468 accuracy= 0.1429
# Test set results: loss= 1.9440 accuracy= 0.2560
# success
# Train set results: loss= 1.9457 accuracy= 0.1500
# Test set results: loss= 1.9433 accuracy= 0.2860
# Train set results: loss= 1.9471 accuracy= 0.1643
# Test set results: loss= 1.9399 accuracy= 0.2520
# Train set results: loss= 1.9473 accuracy= 0.1857
# Test set results: loss= 1.9389 accuracy= 0.2880
# Train set results: loss= 1.9475 accuracy= 0.1643
# Test set results: loss= 1.9423 accuracy= 0.2720
# Train set results: loss= 1.9479 accuracy= 0.1571
# Test set results: loss= 1.9435 accuracy= 0.2800
# Train set results: loss= 1.9468 accuracy= 0.1786
# Test set results: loss= 1.9378 accuracy= 0.3030
# Train set results: loss= 1.9472 accuracy= 0.2286
# Test set results: loss= 1.9414 accuracy= 0.2810
# Train set results: loss= 1.9464 accuracy= 0.1643
# Test set results: loss= 1.9446 accuracy= 0.2630
# Train set results: loss= 1.9471 accuracy= 0.2143
# Test set results: loss= 1.9413 accuracy= 0.2970
# Train set results: loss= 1.9463 accuracy= 0.1500
# Test set results: loss= 1.9442 accuracy= 0.2600
# Train set results: loss= 1.9514 accuracy= 0.1500
# Test set results: loss= 1.9338 accuracy= 0.2730
# Train set results: loss= 1.9474 accuracy= 0.1429
# Test set results: loss= 1.9372 accuracy= 0.2840
# Train set results: loss= 1.9476 accuracy= 0.1357
# Test set results: loss= 1.9378 accuracy= 0.2520
# Train set results: loss= 1.9473 accuracy= 0.1143
# Test set results: loss= 1.9377 accuracy= 0.3050
# Train set results: loss= 1.9464 accuracy= 0.2071
# Test set results: loss= 1.9443 accuracy= 0.2720
# Epoch 0, loss_avg: 2.4724173954554964
# success
# Train set results: loss= 1.9285 accuracy= 0.1929
# Test set results: loss= 1.9425 accuracy= 0.1620
# success
# Train set results: loss= 1.9372 accuracy= 0.1429
# Test set results: loss= 1.9392 accuracy= 0.3040
# success
# Train set results: loss= 3.0441 accuracy= 0.3214
# Test set results: loss= 2.2097 accuracy= 0.2070
# success
# Train set results: loss= 1.9431 accuracy= 0.1357
# Test set results: loss= 1.9413 accuracy= 0.2300
# success
# Train set results: loss= 1.9446 accuracy= 0.1286
# Test set results: loss= 1.9457 accuracy= 0.1590
# success
# Train set results: loss= 1.9426 accuracy= 0.1000
# Test set results: loss= 1.9365 accuracy= 0.2160
# success
# Train set results: loss= 1.9357 accuracy= 0.2643
# Test set results: loss= 1.9457 accuracy= 0.1500
# success
# Train set results: loss= 1.9405 accuracy= 0.1643
# Test set results: loss= 1.9434 accuracy= 0.1490
# success
# Train set results: loss= 1.9452 accuracy= 0.1429
# Test set results: loss= 1.9349 accuracy= 0.3180
# success
# Train set results: loss= 1.9448 accuracy= 0.1429
# Test set results: loss= 1.9410 accuracy= 0.2990
# success
# Train set results: loss= 1.9408 accuracy= 0.1714
# Test set results: loss= 1.9366 accuracy= 0.3160
# success
# Train set results: loss= 3.3567 accuracy= 0.2857
# Test set results: loss= 2.3372 accuracy= 0.1780
# success
# Train set results: loss= 1.9397 accuracy= 0.1500
# Test set results: loss= 1.9394 accuracy= 0.2070
# success
# Train set results: loss= 3.2147 accuracy= 0.3000
# Test set results: loss= 2.2882 accuracy= 0.1730
# success
# Train set results: loss= 1.9426 accuracy= 0.2143
# Test set results: loss= 1.9430 accuracy= 0.3070
# success
# Train set results: loss= 1.9350 accuracy= 0.2000
# Test set results: loss= 1.9393 accuracy= 0.2020
# Train set results: loss= 1.9384 accuracy= 0.1429
# Test set results: loss= 1.9400 accuracy= 0.2100
# Train set results: loss= 1.9257 accuracy= 0.2571
# Test set results: loss= 1.9438 accuracy= 0.1570
# Train set results: loss= 3.1732 accuracy= 0.2857
# Test set results: loss= 2.2604 accuracy= 0.1840
# Train set results: loss= 2.6102 accuracy= 0.2857
# Test set results: loss= 2.1092 accuracy= 0.1810
# Train set results: loss= 2.4749 accuracy= 0.3071
# Test set results: loss= 2.0482 accuracy= 0.2080
# Train set results: loss= 1.9281 accuracy= 0.1929
# Test set results: loss= 1.9402 accuracy= 0.1670
# Train set results: loss= 1.9431 accuracy= 0.1786
# Test set results: loss= 1.9419 accuracy= 0.3110
# Train set results: loss= 1.9291 accuracy= 0.2143
# Test set results: loss= 1.9418 accuracy= 0.1710
# Train set results: loss= 2.5430 accuracy= 0.2857
# Test set results: loss= 2.0747 accuracy= 0.1940
# Train set results: loss= 1.9431 accuracy= 0.1500
# Test set results: loss= 1.9384 accuracy= 0.3070
# Train set results: loss= 2.6750 accuracy= 0.3286
# Test set results: loss= 2.0889 accuracy= 0.2380
# Train set results: loss= 1.9453 accuracy= 0.1429
# Test set results: loss= 1.9361 accuracy= 0.3200
# Train set results: loss= 2.7102 accuracy= 0.2929
# Test set results: loss= 2.1234 accuracy= 0.1770
# Train set results: loss= 1.9403 accuracy= 0.1500
# Test set results: loss= 1.9389 accuracy= 0.2010
# success
# Train set results: loss= 1.9416 accuracy= 0.1429
# Test set results: loss= 1.9385 accuracy= 0.2930
# success
# Train set results: loss= 1.9340 accuracy= 0.1500
# Test set results: loss= 1.9319 accuracy= 0.3180
# success
# Train set results: loss= 2.4505 accuracy= 0.3500
# Test set results: loss= 1.9637 accuracy= 0.1990
# success
# Train set results: loss= 1.8556 accuracy= 0.3286
# Test set results: loss= 1.9203 accuracy= 0.2380
# success
# Train set results: loss= 1.9183 accuracy= 0.2143
# Test set results: loss= 1.9294 accuracy= 0.3330
# success
# Train set results: loss= 1.8408 accuracy= 0.3571
# Test set results: loss= 1.9072 accuracy= 0.3020
# success
# Train set results: loss= 2.8568 accuracy= 0.3286
# Test set results: loss= 2.1935 accuracy= 0.2230
# success
# Train set results: loss= 1.9441 accuracy= 0.1500
# Test set results: loss= 1.9379 accuracy= 0.3170
# success
# Train set results: loss= 1.9378 accuracy= 0.1786
# Test set results: loss= 1.9358 accuracy= 0.3170
# success
# Train set results: loss= 1.8202 accuracy= 0.3286
# Test set results: loss= 1.9085 accuracy= 0.2150
# success
# Train set results: loss= 1.8895 accuracy= 0.2643
# Test set results: loss= 1.9227 accuracy= 0.3390
# success
# Train set results: loss= 1.9155 accuracy= 0.2571
# Test set results: loss= 1.9240 accuracy= 0.3250
# success
# Train set results: loss= 2.5781 accuracy= 0.3571
# Test set results: loss= 2.0319 accuracy= 0.2140
# success
# Train set results: loss= 2.8198 accuracy= 0.3429
# Test set results: loss= 2.1616 accuracy= 0.2210
# success
# Train set results: loss= 2.6300 accuracy= 0.3429
# Test set results: loss= 2.0159 accuracy= 0.2220
# success
# Train set results: loss= 1.6738 accuracy= 0.3571
# Test set results: loss= 1.7767 accuracy= 0.2270
# Train set results: loss= 1.8892 accuracy= 0.3143
# Test set results: loss= 1.9218 accuracy= 0.3480
# Train set results: loss= 1.8777 accuracy= 0.2357
# Test set results: loss= 1.9189 accuracy= 0.3630
# Train set results: loss= 2.8551 accuracy= 0.3357
# Test set results: loss= 2.1850 accuracy= 0.2080
# Train set results: loss= 1.8912 accuracy= 0.2857
# Test set results: loss= 1.9243 accuracy= 0.3280
# Train set results: loss= 1.7461 accuracy= 0.3143
# Test set results: loss= 1.8888 accuracy= 0.2440
# Train set results: loss= 1.9439 accuracy= 0.1571
# Test set results: loss= 1.9423 accuracy= 0.3110
# Train set results: loss= 2.8713 accuracy= 0.3429
# Test set results: loss= 2.2110 accuracy= 0.2110
# Train set results: loss= 1.8400 accuracy= 0.3286
# Test set results: loss= 1.9135 accuracy= 0.2420
# Train set results: loss= 1.9439 accuracy= 0.1429
# Test set results: loss= 1.9368 accuracy= 0.3170
# Train set results: loss= 2.7183 accuracy= 0.3429
# Test set results: loss= 2.0844 accuracy= 0.2120
# Train set results: loss= 1.8993 accuracy= 0.2786
# Test set results: loss= 1.9269 accuracy= 0.2440
# Train set results: loss= 2.6128 accuracy= 0.3214
# Test set results: loss= 2.1325 accuracy= 0.2140
# Train set results: loss= 2.9781 accuracy= 0.3429
# Test set results: loss= 2.2749 accuracy= 0.2220
# Train set results: loss= 2.7450 accuracy= 0.3429
# Test set results: loss= 2.1863 accuracy= 0.2020
# success
# Train set results: loss= 3.2311 accuracy= 0.2929
# Test set results: loss= 2.6688 accuracy= 0.2800
# success
# Train set results: loss= 1.9232 accuracy= 0.3571
# Test set results: loss= 1.8303 accuracy= 0.2760
# success
# Train set results: loss= 3.0884 accuracy= 0.3286
# Test set results: loss= 2.5889 accuracy= 0.2740
# success
# Train set results: loss= 1.8580 accuracy= 0.3786
# Test set results: loss= 1.8821 accuracy= 0.2690
# success
# Train set results: loss= 2.4948 accuracy= 0.3000
# Test set results: loss= 2.1335 accuracy= 0.2860
# success
# Train set results: loss= 2.4875 accuracy= 0.3214
# Test set results: loss= 2.2195 accuracy= 0.2630
# success
# Train set results: loss= 2.5823 accuracy= 0.3214
# Test set results: loss= 2.1796 accuracy= 0.2730
# success
# Train set results: loss= 2.5486 accuracy= 0.3143
# Test set results: loss= 2.2250 accuracy= 0.2670
# success
# Train set results: loss= 2.8637 accuracy= 0.2929
# Test set results: loss= 2.4350 accuracy= 0.2670
# success
# Train set results: loss= 2.4654 accuracy= 0.3071
# Test set results: loss= 2.1329 accuracy= 0.2700
# success
# Train set results: loss= 1.9058 accuracy= 0.2929
# Test set results: loss= 1.9265 accuracy= 0.3770
# success
# Train set results: loss= 3.0215 accuracy= 0.3071
# Test set results: loss= 2.4098 accuracy= 0.2660
# success
# Train set results: loss= 1.7480 accuracy= 0.3571
# Test set results: loss= 1.7618 accuracy= 0.2770
# success
# Train set results: loss= 1.6042 accuracy= 0.3857
# Test set results: loss= 1.7186 accuracy= 0.2750
# success
# Train set results: loss= 1.8425 accuracy= 0.2786
# Test set results: loss= 1.9093 accuracy= 0.3410
# success
# Train set results: loss= 3.1175 accuracy= 0.3143
# Test set results: loss= 2.5025 accuracy= 0.2860
# Train set results: loss= 1.6382 accuracy= 0.3929
# Test set results: loss= 1.7530 accuracy= 0.2630
# Train set results: loss= 2.6978 accuracy= 0.3357
# Test set results: loss= 2.2805 accuracy= 0.2730
# Train set results: loss= 2.5993 accuracy= 0.3286
# Test set results: loss= 2.0812 accuracy= 0.2860
# Train set results: loss= 2.1239 accuracy= 0.3357
# Test set results: loss= 1.9650 accuracy= 0.2810
# Train set results: loss= 2.7752 accuracy= 0.3214
# Test set results: loss= 2.3906 accuracy= 0.2650
# Train set results: loss= 3.1365 accuracy= 0.3143
# Test set results: loss= 2.5746 accuracy= 0.2730
# Train set results: loss= 2.9262 accuracy= 0.2929
# Test set results: loss= 2.3874 accuracy= 0.2800
# Train set results: loss= 2.3844 accuracy= 0.3500
# Test set results: loss= 2.0860 accuracy= 0.2950
# Train set results: loss= 2.1539 accuracy= 0.3429
# Test set results: loss= 1.9567 accuracy= 0.2760
# Train set results: loss= 2.6378 accuracy= 0.3143
# Test set results: loss= 2.1246 accuracy= 0.2610
# Train set results: loss= 3.1274 accuracy= 0.3071
# Test set results: loss= 2.4973 accuracy= 0.2740
# Train set results: loss= 2.4231 accuracy= 0.3429
# Test set results: loss= 2.2304 accuracy= 0.2760
# Train set results: loss= 1.9957 accuracy= 0.3429
# Test set results: loss= 1.8522 accuracy= 0.2800
# Train set results: loss= 3.1837 accuracy= 0.3143
# Test set results: loss= 2.5625 accuracy= 0.2700
# success
# Train set results: loss= 1.7519 accuracy= 0.2714
# Test set results: loss= 1.8055 accuracy= 0.2720
# success
# Train set results: loss= 1.9439 accuracy= 0.1714
# Test set results: loss= 1.9400 accuracy= 0.3080
# success
# Train set results: loss= 1.9436 accuracy= 0.1429
# Test set results: loss= 1.9351 accuracy= 0.3190
# success
# Train set results: loss= 1.7595 accuracy= 0.3071
# Test set results: loss= 1.7728 accuracy= 0.2660
# success
# Train set results: loss= 2.3025 accuracy= 0.2786
# Test set results: loss= 1.9865 accuracy= 0.2720
# success
# Train set results: loss= 1.8977 accuracy= 0.2429
# Test set results: loss= 1.9271 accuracy= 0.2960
# success
# Train set results: loss= 1.9546 accuracy= 0.3000
# Test set results: loss= 1.8607 accuracy= 0.2720
# success
# Train set results: loss= 2.8892 accuracy= 0.2571
# Test set results: loss= 2.3921 accuracy= 0.2850
# success
# Train set results: loss= 1.6390 accuracy= 0.3000
# Test set results: loss= 1.7485 accuracy= 0.2890
# success
# Train set results: loss= 1.6243 accuracy= 0.3000
# Test set results: loss= 1.7388 accuracy= 0.2780
# success
# Train set results: loss= 2.3974 accuracy= 0.2786
# Test set results: loss= 2.0680 accuracy= 0.2780
# success
# Train set results: loss= 1.7131 accuracy= 0.3214
# Test set results: loss= 1.7665 accuracy= 0.2960
# success
# Train set results: loss= 2.6470 accuracy= 0.2786
# Test set results: loss= 2.2315 accuracy= 0.2720
# success
# Train set results: loss= 1.5894 accuracy= 0.3000
# Test set results: loss= 1.7473 accuracy= 0.2670
# success
# Train set results: loss= 2.0752 accuracy= 0.2857
# Test set results: loss= 1.9751 accuracy= 0.2680
# success
# Train set results: loss= 1.9308 accuracy= 0.2643
# Test set results: loss= 1.9367 accuracy= 0.3340
# Train set results: loss= 1.6238 accuracy= 0.3000
# Test set results: loss= 1.7379 accuracy= 0.2750
# Train set results: loss= 1.6404 accuracy= 0.2786
# Test set results: loss= 1.7730 accuracy= 0.2730
# Train set results: loss= 1.7398 accuracy= 0.3214
# Test set results: loss= 1.7773 accuracy= 0.2910
# Train set results: loss= 2.0729 accuracy= 0.2786
# Test set results: loss= 1.8991 accuracy= 0.2810
# Train set results: loss= 1.5818 accuracy= 0.3286
# Test set results: loss= 1.7505 accuracy= 0.2720
# Train set results: loss= 1.7632 accuracy= 0.3357
# Test set results: loss= 1.7890 accuracy= 0.2940
# Train set results: loss= 1.5842 accuracy= 0.3000
# Test set results: loss= 1.7659 accuracy= 0.2840
# Train set results: loss= 1.7290 accuracy= 0.2786
# Test set results: loss= 1.7756 accuracy= 0.2740
# Train set results: loss= 1.9052 accuracy= 0.2571
# Test set results: loss= 1.9302 accuracy= 0.3030
# Train set results: loss= 1.5926 accuracy= 0.2929
# Test set results: loss= 1.7527 accuracy= 0.2820
# Train set results: loss= 1.7011 accuracy= 0.3429
# Test set results: loss= 1.7750 accuracy= 0.3020
# Train set results: loss= 1.9406 accuracy= 0.2429
# Test set results: loss= 1.9406 accuracy= 0.3640
# Train set results: loss= 1.8375 accuracy= 0.3143
# Test set results: loss= 1.8234 accuracy= 0.2780
# Train set results: loss= 1.7787 accuracy= 0.3071
# Test set results: loss= 1.7901 accuracy= 0.2930
# success
# Train set results: loss= 1.8893 accuracy= 0.2786
# Test set results: loss= 1.8421 accuracy= 0.2460
# success
# Train set results: loss= 1.7298 accuracy= 0.3071
# Test set results: loss= 1.7722 accuracy= 0.2520
# success
# Train set results: loss= 1.6733 accuracy= 0.2929
# Test set results: loss= 1.7588 accuracy= 0.2760
# success
# Train set results: loss= 1.7635 accuracy= 0.2714
# Test set results: loss= 1.7663 accuracy= 0.2540
# success
# Train set results: loss= 1.9434 accuracy= 0.1429
# Test set results: loss= 1.9369 accuracy= 0.3190
# success
# Train set results: loss= 1.6739 accuracy= 0.2786
# Test set results: loss= 1.7600 accuracy= 0.2570
# success
# Train set results: loss= 1.9435 accuracy= 0.2143
# Test set results: loss= 1.9402 accuracy= 0.3320
# success
# Train set results: loss= 1.6362 accuracy= 0.2929
# Test set results: loss= 1.7814 accuracy= 0.2770
# success
# Train set results: loss= 1.7154 accuracy= 0.2714
# Test set results: loss= 1.7627 accuracy= 0.2650
# success
# Train set results: loss= 1.6826 accuracy= 0.2714
# Test set results: loss= 1.7527 accuracy= 0.2760
# success
# Train set results: loss= 1.6795 accuracy= 0.2786
# Test set results: loss= 1.7748 accuracy= 0.2660
# success
# Train set results: loss= 2.0549 accuracy= 0.2857
# Test set results: loss= 1.8713 accuracy= 0.2770
# success
# Train set results: loss= 1.6662 accuracy= 0.3000
# Test set results: loss= 1.7551 accuracy= 0.2400
# success
# Train set results: loss= 1.7664 accuracy= 0.2786
# Test set results: loss= 1.7793 accuracy= 0.2620
# success
# Train set results: loss= 1.9488 accuracy= 0.2643
# Test set results: loss= 1.8045 accuracy= 0.2580
# success
# Train set results: loss= 2.2255 accuracy= 0.2643
# Test set results: loss= 1.9265 accuracy= 0.2560
# Train set results: loss= 2.6593 accuracy= 0.2500
# Test set results: loss= 2.1896 accuracy= 0.2440
# Train set results: loss= 1.6251 accuracy= 0.2929
# Test set results: loss= 1.7763 accuracy= 0.2770
# Train set results: loss= 1.6740 accuracy= 0.2857
# Test set results: loss= 1.7639 accuracy= 0.2640
# Train set results: loss= 1.6709 accuracy= 0.2857
# Test set results: loss= 1.7971 accuracy= 0.2700
# Train set results: loss= 1.9442 accuracy= 0.1429
# Test set results: loss= 1.9355 accuracy= 0.3190
# Train set results: loss= 1.9442 accuracy= 0.1929
# Test set results: loss= 1.9396 accuracy= 0.3280
# Train set results: loss= 1.7412 accuracy= 0.2786
# Test set results: loss= 1.7711 accuracy= 0.2520
# Train set results: loss= 1.9133 accuracy= 0.2857
# Test set results: loss= 1.9417 accuracy= 0.2610
# Train set results: loss= 1.9428 accuracy= 0.1571
# Test set results: loss= 1.9397 accuracy= 0.3240
# Train set results: loss= 1.6606 accuracy= 0.2786
# Test set results: loss= 1.7737 accuracy= 0.2580
# Train set results: loss= 1.7137 accuracy= 0.2786
# Test set results: loss= 1.7799 accuracy= 0.2580
# Train set results: loss= 2.1973 accuracy= 0.2571
# Test set results: loss= 1.9268 accuracy= 0.2710
# Train set results: loss= 1.9436 accuracy= 0.2071
# Test set results: loss= 1.9408 accuracy= 0.3210
# Train set results: loss= 1.9165 accuracy= 0.2714
# Test set results: loss= 1.9352 accuracy= 0.3820
# success
# Train set results: loss= 1.9411 accuracy= 0.1500
# Test set results: loss= 1.9403 accuracy= 0.3060
# success
# Train set results: loss= 1.6850 accuracy= 0.2500
# Test set results: loss= 1.7837 accuracy= 0.2380
# success
# Train set results: loss= 1.7371 accuracy= 0.2571
# Test set results: loss= 1.7752 accuracy= 0.2210
# success
# Train set results: loss= 1.6928 accuracy= 0.2929
# Test set results: loss= 1.7879 accuracy= 0.2680
# success
# Train set results: loss= 1.7191 accuracy= 0.2714
# Test set results: loss= 1.7865 accuracy= 0.2350
# success
# Train set results: loss= 1.9497 accuracy= 0.2571
# Test set results: loss= 1.8463 accuracy= 0.2410
# success
# Train set results: loss= 1.6488 accuracy= 0.2786
# Test set results: loss= 1.8205 accuracy= 0.2600
# success
# Train set results: loss= 1.6566 accuracy= 0.2500
# Test set results: loss= 1.7848 accuracy= 0.2420
# success
# Train set results: loss= 1.6710 accuracy= 0.3071
# Test set results: loss= 1.8609 accuracy= 0.2070
# success
# Train set results: loss= 1.6630 accuracy= 0.2643
# Test set results: loss= 1.7925 accuracy= 0.2390
# success
# Train set results: loss= 1.7358 accuracy= 0.2714
# Test set results: loss= 1.8019 accuracy= 0.2490
# success
# Train set results: loss= 1.7041 accuracy= 0.2857
# Test set results: loss= 1.8023 accuracy= 0.2330
# success
# Train set results: loss= 1.8693 accuracy= 0.2714
# Test set results: loss= 1.8154 accuracy= 0.2330
# success
# Train set results: loss= 1.6656 accuracy= 0.2786
# Test set results: loss= 1.8318 accuracy= 0.2690
# success
# Train set results: loss= 1.7627 accuracy= 0.2714
# Test set results: loss= 1.8048 accuracy= 0.2740
# success
# Train set results: loss= 1.6431 accuracy= 0.2857
# Test set results: loss= 1.8199 accuracy= 0.2450
# Train set results: loss= 1.6848 accuracy= 0.2786
# Test set results: loss= 1.8129 accuracy= 0.2800
# Train set results: loss= 1.6870 accuracy= 0.2857
# Test set results: loss= 1.7871 accuracy= 0.2650
# Train set results: loss= 1.6687 accuracy= 0.2929
# Test set results: loss= 1.8072 accuracy= 0.2570
# Train set results: loss= 1.9312 accuracy= 0.2643
# Test set results: loss= 1.9410 accuracy= 0.2540
# Train set results: loss= 1.7428 accuracy= 0.2857
# Test set results: loss= 1.8855 accuracy= 0.2840
# Train set results: loss= 1.7506 accuracy= 0.2714
# Test set results: loss= 1.8106 accuracy= 0.2550
# Train set results: loss= 1.6719 accuracy= 0.2786
# Test set results: loss= 1.8150 accuracy= 0.2570
# Train set results: loss= 1.6374 accuracy= 0.3000
# Test set results: loss= 1.7703 accuracy= 0.2640
# Train set results: loss= 1.6605 accuracy= 0.2643
# Test set results: loss= 1.8114 accuracy= 0.2290
# Train set results: loss= 1.7558 accuracy= 0.2643
# Test set results: loss= 1.7860 accuracy= 0.2580
# Train set results: loss= 1.7459 accuracy= 0.2929
# Test set results: loss= 1.7813 accuracy= 0.2350
# Train set results: loss= 1.7641 accuracy= 0.2429
# Test set results: loss= 1.7913 accuracy= 0.2260
# Train set results: loss= 1.6340 accuracy= 0.3000
# Test set results: loss= 1.7978 accuracy= 0.2710
# Train set results: loss= 1.9344 accuracy= 0.2643
# Test set results: loss= 1.9404 accuracy= 0.3200
# success
# Train set results: loss= 1.8322 accuracy= 0.2714
# Test set results: loss= 1.9120 accuracy= 0.2260
# success
# Train set results: loss= 1.6699 accuracy= 0.2786
# Test set results: loss= 1.8101 accuracy= 0.2520
# success
# Train set results: loss= 1.7152 accuracy= 0.2714
# Test set results: loss= 1.8061 accuracy= 0.2330
# success
# Train set results: loss= 1.7584 accuracy= 0.2643
# Test set results: loss= 1.7944 accuracy= 0.2390
# success
# Train set results: loss= 1.6811 accuracy= 0.2429
# Test set results: loss= 1.7704 accuracy= 0.2430
# success
# Train set results: loss= 1.6792 accuracy= 0.2643
# Test set results: loss= 1.8485 accuracy= 0.2200
# success
# Train set results: loss= 1.8103 accuracy= 0.2643
# Test set results: loss= 1.8118 accuracy= 0.2330
# success
# Train set results: loss= 1.6584 accuracy= 0.2714
# Test set results: loss= 1.8231 accuracy= 0.2460
# success
# Train set results: loss= 1.6525 accuracy= 0.3000
# Test set results: loss= 1.8090 accuracy= 0.2450
# success
# Train set results: loss= 1.6770 accuracy= 0.2571
# Test set results: loss= 1.8070 accuracy= 0.2550
# success
# Train set results: loss= 1.7207 accuracy= 0.2500
# Test set results: loss= 1.7936 accuracy= 0.2210
# success
# Train set results: loss= 1.7193 accuracy= 0.2643
# Test set results: loss= 1.7843 accuracy= 0.2400
# success
# Train set results: loss= 1.7985 accuracy= 0.2500
# Test set results: loss= 1.7837 accuracy= 0.2470
# success
# Train set results: loss= 1.9125 accuracy= 0.3000
# Test set results: loss= 1.9372 accuracy= 0.2610
# success
# Train set results: loss= 1.6449 accuracy= 0.2857
# Test set results: loss= 1.8304 accuracy= 0.2260
# success
# Train set results: loss= 1.7096 accuracy= 0.2786
# Test set results: loss= 1.8030 accuracy= 0.2390
# Train set results: loss= 1.9308 accuracy= 0.2214
# Test set results: loss= 1.9387 accuracy= 0.3010
# Train set results: loss= 1.9437 accuracy= 0.1429
# Test set results: loss= 1.9367 accuracy= 0.3180
# Train set results: loss= 1.6637 accuracy= 0.2714
# Test set results: loss= 1.8201 accuracy= 0.2240
# Train set results: loss= 3.0847 accuracy= 0.2357
# Test set results: loss= 2.1912 accuracy= 0.2110
# Train set results: loss= 1.9403 accuracy= 0.2500
# Test set results: loss= 1.9419 accuracy= 0.3680
# Train set results: loss= 1.8987 accuracy= 0.2786
# Test set results: loss= 1.9295 accuracy= 0.3480
# Train set results: loss= 1.8813 accuracy= 0.3071
# Test set results: loss= 1.9330 accuracy= 0.3010
# Train set results: loss= 1.9098 accuracy= 0.2286
# Test set results: loss= 1.9305 accuracy= 0.2830
# Train set results: loss= 1.6651 accuracy= 0.2571
# Test set results: loss= 1.8120 accuracy= 0.2420
# Train set results: loss= 1.6726 accuracy= 0.2786
# Test set results: loss= 1.8090 accuracy= 0.2430
# Train set results: loss= 1.6621 accuracy= 0.2786
# Test set results: loss= 1.8276 accuracy= 0.2360
# Train set results: loss= 1.6514 accuracy= 0.2643
# Test set results: loss= 1.8305 accuracy= 0.2210
# Train set results: loss= 1.7338 accuracy= 0.2643
# Test set results: loss= 1.7858 accuracy= 0.2500
# Train set results: loss= 1.7839 accuracy= 0.2429
# Test set results: loss= 1.7976 accuracy= 0.2420
# success
# Train set results: loss= 1.6572 accuracy= 0.2643
# Test set results: loss= 1.8298 accuracy= 0.2410
# success
# Train set results: loss= 1.7185 accuracy= 0.2571
# Test set results: loss= 1.8336 accuracy= 0.2100
# success
# Train set results: loss= 1.6605 accuracy= 0.2643
# Test set results: loss= 1.8480 accuracy= 0.2260
# success
# Train set results: loss= 1.8034 accuracy= 0.2714
# Test set results: loss= 1.9099 accuracy= 0.2370
# success
# Train set results: loss= 1.6754 accuracy= 0.2929
# Test set results: loss= 1.8217 accuracy= 0.2200
# success
# Train set results: loss= 3.3122 accuracy= 0.2357
# Test set results: loss= 2.3704 accuracy= 0.1840
# success
# Train set results: loss= 1.6832 accuracy= 0.2714
# Test set results: loss= 1.8287 accuracy= 0.2250
# success
# Train set results: loss= 1.6987 accuracy= 0.2643
# Test set results: loss= 1.8173 accuracy= 0.2260
# success
# Train set results: loss= 1.6741 accuracy= 0.2714
# Test set results: loss= 1.8279 accuracy= 0.2340
# success
# Train set results: loss= 1.6778 accuracy= 0.2643
# Test set results: loss= 1.8324 accuracy= 0.2500
# success
# Train set results: loss= 1.8955 accuracy= 0.3071
# Test set results: loss= 1.9332 accuracy= 0.2230
# success
# Train set results: loss= 1.7072 accuracy= 0.2643
# Test set results: loss= 1.7888 accuracy= 0.2340
# success
# Train set results: loss= 1.6911 accuracy= 0.2571
# Test set results: loss= 1.8073 accuracy= 0.2210
# success
# Train set results: loss= 1.8995 accuracy= 0.3071
# Test set results: loss= 1.9344 accuracy= 0.2440
# success
# Train set results: loss= 1.6714 accuracy= 0.2714
# Test set results: loss= 1.8231 accuracy= 0.2370
# success
# Train set results: loss= 1.6703 accuracy= 0.2714
# Test set results: loss= 1.8102 accuracy= 0.2460
# Train set results: loss= 1.7134 accuracy= 0.2714
# Test set results: loss= 1.8143 accuracy= 0.2230
# Train set results: loss= 1.9068 accuracy= 0.2786
# Test set results: loss= 1.9358 accuracy= 0.2280
# Train set results: loss= 1.6603 accuracy= 0.2786
# Test set results: loss= 1.8140 accuracy= 0.2370
# Train set results: loss= 1.6995 accuracy= 0.2857
# Test set results: loss= 1.8236 accuracy= 0.2520
# Train set results: loss= 1.9442 accuracy= 0.1571
# Test set results: loss= 1.9395 accuracy= 0.3170
# Train set results: loss= 1.8723 accuracy= 0.2143
# Test set results: loss= 1.9179 accuracy= 0.2810
# Train set results: loss= 1.6891 accuracy= 0.2643
# Test set results: loss= 1.8241 accuracy= 0.2040
# Train set results: loss= 1.8213 accuracy= 0.2429
# Test set results: loss= 1.8157 accuracy= 0.2290
# Train set results: loss= 1.8391 accuracy= 0.2643
# Test set results: loss= 1.9160 accuracy= 0.2400
# Train set results: loss= 1.9359 accuracy= 0.2429
# Test set results: loss= 1.9418 accuracy= 0.3760
# Train set results: loss= 1.7013 accuracy= 0.2571
# Test set results: loss= 1.7919 accuracy= 0.2360
# Train set results: loss= 1.7001 accuracy= 0.2429
# Test set results: loss= 1.8395 accuracy= 0.2030
# Train set results: loss= 1.9304 accuracy= 0.2500
# Test set results: loss= 1.9405 accuracy= 0.3220
# Train set results: loss= 1.8945 accuracy= 0.2643
# Test set results: loss= 1.9303 accuracy= 0.2700
# success
# Train set results: loss= 1.8950 accuracy= 0.2714
# Test set results: loss= 1.9312 accuracy= 0.2710
# success
# Train set results: loss= 1.6929 accuracy= 0.2714
# Test set results: loss= 1.8459 accuracy= 0.2240
# success
# Train set results: loss= 1.6880 accuracy= 0.2643
# Test set results: loss= 1.8478 accuracy= 0.2210
# success
# Train set results: loss= 2.2396 accuracy= 0.2500
# Test set results: loss= 1.9085 accuracy= 0.2050
# success
# Train set results: loss= 1.9171 accuracy= 0.2643
# Test set results: loss= 1.9353 accuracy= 0.2730
# success
# Train set results: loss= 1.7036 accuracy= 0.2714
# Test set results: loss= 1.8623 accuracy= 0.2220
# success
# Train set results: loss= 1.6872 accuracy= 0.2714
# Test set results: loss= 1.8327 accuracy= 0.2440
# success
# Train set results: loss= 1.9434 accuracy= 0.1571
# Test set results: loss= 1.9405 accuracy= 0.3190
# success
# Train set results: loss= 1.9029 accuracy= 0.2643
# Test set results: loss= 1.9278 accuracy= 0.2900
# success
# Train set results: loss= 1.9297 accuracy= 0.2357
# Test set results: loss= 1.9391 accuracy= 0.2430
# success
# Train set results: loss= 1.9439 accuracy= 0.2357
# Test set results: loss= 1.9430 accuracy= 0.3270
# success
# Train set results: loss= 1.6821 accuracy= 0.2714
# Test set results: loss= 1.8382 accuracy= 0.2220
# success
# Train set results: loss= 1.6931 accuracy= 0.2643
# Test set results: loss= 1.8533 accuracy= 0.2210
# success
# Train set results: loss= 1.6942 accuracy= 0.2643
# Test set results: loss= 1.8420 accuracy= 0.2240
# success
# Train set results: loss= 1.7038 accuracy= 0.2643
# Test set results: loss= 1.8626 accuracy= 0.2210
# success
# Train set results: loss= 1.7147 accuracy= 0.2714
# Test set results: loss= 1.8753 accuracy= 0.2040
# Train set results: loss= 1.9353 accuracy= 0.2357
# Test set results: loss= 1.9415 accuracy= 0.2190
# Train set results: loss= 1.6584 accuracy= 0.2643
# Test set results: loss= 1.8150 accuracy= 0.2310
# Train set results: loss= 1.9403 accuracy= 0.2500
# Test set results: loss= 1.9431 accuracy= 0.2950
# Train set results: loss= 1.6988 accuracy= 0.2643
# Test set results: loss= 1.8380 accuracy= 0.2260
# Train set results: loss= 3.2900 accuracy= 0.2429
# Test set results: loss= 2.3892 accuracy= 0.2060
# Train set results: loss= 1.7090 accuracy= 0.2500
# Test set results: loss= 1.8054 accuracy= 0.2170
# Train set results: loss= 1.9295 accuracy= 0.2429
# Test set results: loss= 1.9388 accuracy= 0.3340
# Train set results: loss= 1.7150 accuracy= 0.2500
# Test set results: loss= 1.8191 accuracy= 0.2480
# Train set results: loss= 1.8455 accuracy= 0.2429
# Test set results: loss= 1.8126 accuracy= 0.2180
# Train set results: loss= 1.7075 accuracy= 0.2643
# Test set results: loss= 1.8327 accuracy= 0.2070
# Train set results: loss= 1.8206 accuracy= 0.2857
# Test set results: loss= 1.9091 accuracy= 0.2130
# Train set results: loss= 1.7128 accuracy= 0.2714
# Test set results: loss= 1.8355 accuracy= 0.2000
# Train set results: loss= 3.2017 accuracy= 0.2357
# Test set results: loss= 2.4009 accuracy= 0.2210
# Train set results: loss= 1.6995 accuracy= 0.2714
# Test set results: loss= 1.8594 accuracy= 0.2070
# success
# Train set results: loss= 1.7769 accuracy= 0.4000
# Test set results: loss= 1.8912 accuracy= 0.3200
# success
# Train set results: loss= 1.8310 accuracy= 0.3714
# Test set results: loss= 1.9018 accuracy= 0.3590
# success
# Train set results: loss= 1.9261 accuracy= 0.4214
# Test set results: loss= 1.9354 accuracy= 0.3570
# success
# Train set results: loss= 1.9014 accuracy= 0.3857
# Test set results: loss= 1.9269 accuracy= 0.3560
# success
# Train set results: loss= 1.7287 accuracy= 0.4143
# Test set results: loss= 1.8760 accuracy= 0.2720
# success
# Train set results: loss= 1.5989 accuracy= 0.4000
# Test set results: loss= 1.8195 accuracy= 0.3110
# success
# Train set results: loss= 1.8887 accuracy= 0.3857
# Test set results: loss= 1.9246 accuracy= 0.3890
# success
# Train set results: loss= 1.6091 accuracy= 0.3857
# Test set results: loss= 1.8332 accuracy= 0.2870
# success
# Train set results: loss= 1.6378 accuracy= 0.4357
# Test set results: loss= 1.8405 accuracy= 0.3150
# success
# Train set results: loss= 1.9113 accuracy= 0.3714
# Test set results: loss= 1.9301 accuracy= 0.3570
# success
# Train set results: loss= 1.9050 accuracy= 0.4071
# Test set results: loss= 1.9278 accuracy= 0.3760
# success
# Train set results: loss= 1.8611 accuracy= 0.3714
# Test set results: loss= 1.9160 accuracy= 0.3130
# success
# Train set results: loss= 1.5444 accuracy= 0.4000
# Test set results: loss= 1.7614 accuracy= 0.2780
# success
# Train set results: loss= 1.5415 accuracy= 0.4071
# Test set results: loss= 1.7845 accuracy= 0.2990
# success
# Train set results: loss= 1.5577 accuracy= 0.4071
# Test set results: loss= 1.7704 accuracy= 0.2990
# success
# Train set results: loss= 1.9223 accuracy= 0.3929
# Test set results: loss= 1.9349 accuracy= 0.4130
# Train set results: loss= 1.8966 accuracy= 0.4143
# Test set results: loss= 1.9323 accuracy= 0.3040
# Train set results: loss= 1.8891 accuracy= 0.4214
# Test set results: loss= 1.9250 accuracy= 0.3690
# Train set results: loss= 1.5737 accuracy= 0.3643
# Test set results: loss= 1.8060 accuracy= 0.3040
# Train set results: loss= 1.6857 accuracy= 0.4143
# Test set results: loss= 1.8550 accuracy= 0.2900
# Train set results: loss= 1.5332 accuracy= 0.3929
# Test set results: loss= 1.7490 accuracy= 0.2950
# Train set results: loss= 1.5539 accuracy= 0.3929
# Test set results: loss= 1.7977 accuracy= 0.3010
# Train set results: loss= 1.5594 accuracy= 0.3929
# Test set results: loss= 1.7952 accuracy= 0.2690
# Train set results: loss= 1.8804 accuracy= 0.4143
# Test set results: loss= 1.9193 accuracy= 0.4210
# Train set results: loss= 1.9230 accuracy= 0.3429
# Test set results: loss= 1.9335 accuracy= 0.3560
# Train set results: loss= 1.9014 accuracy= 0.4143
# Test set results: loss= 1.9269 accuracy= 0.3500
# Train set results: loss= 1.6248 accuracy= 0.3929
# Test set results: loss= 1.8300 accuracy= 0.2740
# Train set results: loss= 1.9218 accuracy= 0.3857
# Test set results: loss= 1.9358 accuracy= 0.3270
# Train set results: loss= 1.6013 accuracy= 0.4071
# Test set results: loss= 1.8231 accuracy= 0.3150
# Train set results: loss= 1.9301 accuracy= 0.3000
# Test set results: loss= 1.9375 accuracy= 0.3510
# success
# Train set results: loss= 1.3376 accuracy= 0.4929
# Test set results: loss= 1.6363 accuracy= 0.3730
# success
# Train set results: loss= 1.8711 accuracy= 0.5286
# Test set results: loss= 1.9195 accuracy= 0.4660
# success
# Train set results: loss= 1.7851 accuracy= 0.5429
# Test set results: loss= 1.8842 accuracy= 0.4580
# success
# Train set results: loss= 1.9268 accuracy= 0.4857
# Test set results: loss= 1.9372 accuracy= 0.4120
# success
# Train set results: loss= 1.7168 accuracy= 0.5143
# Test set results: loss= 1.8663 accuracy= 0.4090
# success
# Train set results: loss= 1.8497 accuracy= 0.5571
# Test set results: loss= 1.9078 accuracy= 0.4760
# success
# Train set results: loss= 1.8486 accuracy= 0.5000
# Test set results: loss= 1.9069 accuracy= 0.5000
# success
# Train set results: loss= 1.8439 accuracy= 0.5357
# Test set results: loss= 1.9121 accuracy= 0.4010
# success
# Train set results: loss= 1.8242 accuracy= 0.5429
# Test set results: loss= 1.9025 accuracy= 0.4550
# success
# Train set results: loss= 1.7844 accuracy= 0.4929
# Test set results: loss= 1.8896 accuracy= 0.3810
# success
# Train set results: loss= 1.8863 accuracy= 0.5929
# Test set results: loss= 1.9196 accuracy= 0.4540
# success
# Train set results: loss= 1.8753 accuracy= 0.5929
# Test set results: loss= 1.9190 accuracy= 0.4280
# success
# Train set results: loss= 1.8726 accuracy= 0.5929
# Test set results: loss= 1.9142 accuracy= 0.4290
# success
# Train set results: loss= 1.8173 accuracy= 0.5429
# Test set results: loss= 1.8912 accuracy= 0.4980
# success
# Train set results: loss= 1.9141 accuracy= 0.5857
# Test set results: loss= 1.9339 accuracy= 0.4550
# success
# Train set results: loss= 1.8330 accuracy= 0.4714
# Test set results: loss= 1.9067 accuracy= 0.4020
# Train set results: loss= 1.9022 accuracy= 0.4857
# Test set results: loss= 1.9275 accuracy= 0.4440
# Train set results: loss= 1.8254 accuracy= 0.5643
# Test set results: loss= 1.9006 accuracy= 0.4600
# Train set results: loss= 1.8518 accuracy= 0.5429
# Test set results: loss= 1.9070 accuracy= 0.4420
# Train set results: loss= 1.9144 accuracy= 0.4357
# Test set results: loss= 1.9346 accuracy= 0.4100
# Train set results: loss= 1.9200 accuracy= 0.5286
# Test set results: loss= 1.9334 accuracy= 0.4530
# Train set results: loss= 1.6124 accuracy= 0.5000
# Test set results: loss= 1.8248 accuracy= 0.3680
# Train set results: loss= 1.7955 accuracy= 0.5500
# Test set results: loss= 1.8976 accuracy= 0.3980
# Train set results: loss= 1.8314 accuracy= 0.5143
# Test set results: loss= 1.9048 accuracy= 0.4120
# Train set results: loss= 1.8658 accuracy= 0.5286
# Test set results: loss= 1.9198 accuracy= 0.4070
# Train set results: loss= 1.4306 accuracy= 0.5143
# Test set results: loss= 1.7467 accuracy= 0.3710
# Train set results: loss= 1.5166 accuracy= 0.5000
# Test set results: loss= 1.7857 accuracy= 0.3840
# Train set results: loss= 1.8229 accuracy= 0.5643
# Test set results: loss= 1.8980 accuracy= 0.4890
# Train set results: loss= 1.7291 accuracy= 0.5143
# Test set results: loss= 1.8726 accuracy= 0.3750
# Train set results: loss= 1.6863 accuracy= 0.5214
# Test set results: loss= 1.8577 accuracy= 0.4000
# success
# Train set results: loss= 1.8011 accuracy= 0.6357
# Test set results: loss= 1.8872 accuracy= 0.5860
# success
# Train set results: loss= 1.8406 accuracy= 0.6857
# Test set results: loss= 1.9025 accuracy= 0.5500
# success
# Train set results: loss= 1.8958 accuracy= 0.6643
# Test set results: loss= 1.9236 accuracy= 0.5890
# success
# Train set results: loss= 1.7455 accuracy= 0.6714
# Test set results: loss= 1.8685 accuracy= 0.5130
# success
# Train set results: loss= 1.6997 accuracy= 0.6571
# Test set results: loss= 1.8521 accuracy= 0.5390
# success
# Train set results: loss= 1.8359 accuracy= 0.6643
# Test set results: loss= 1.9073 accuracy= 0.5220
# success
# Train set results: loss= 1.2990 accuracy= 0.6214
# Test set results: loss= 1.6750 accuracy= 0.5060
# success
# Train set results: loss= 1.8455 accuracy= 0.6357
# Test set results: loss= 1.9005 accuracy= 0.5720
# success
# Train set results: loss= 1.8381 accuracy= 0.7357
# Test set results: loss= 1.9007 accuracy= 0.5880
# success
# Train set results: loss= 1.8075 accuracy= 0.6714
# Test set results: loss= 1.8910 accuracy= 0.5810
# success
# Train set results: loss= 1.7209 accuracy= 0.6357
# Test set results: loss= 1.8630 accuracy= 0.5230
# success
# Train set results: loss= 1.6744 accuracy= 0.6714
# Test set results: loss= 1.8482 accuracy= 0.5110
# success
# Train set results: loss= 1.8828 accuracy= 0.7143
# Test set results: loss= 1.9199 accuracy= 0.5870
# success
# Train set results: loss= 1.7578 accuracy= 0.6786
# Test set results: loss= 1.8756 accuracy= 0.5020
# success
# Train set results: loss= 1.8758 accuracy= 0.6643
# Test set results: loss= 1.9171 accuracy= 0.5980
# success
# Train set results: loss= 1.8182 accuracy= 0.6929
# Test set results: loss= 1.8939 accuracy= 0.6010
# Train set results: loss= 1.8555 accuracy= 0.6857
# Test set results: loss= 1.9078 accuracy= 0.6230
# Train set results: loss= 1.6157 accuracy= 0.6571
# Test set results: loss= 1.8211 accuracy= 0.5230
# Train set results: loss= 1.7696 accuracy= 0.6571
# Test set results: loss= 1.8810 accuracy= 0.5250
# Train set results: loss= 1.7326 accuracy= 0.6857
# Test set results: loss= 1.8638 accuracy= 0.5400
# Train set results: loss= 1.7795 accuracy= 0.6714
# Test set results: loss= 1.8868 accuracy= 0.5290
# Train set results: loss= 1.6628 accuracy= 0.6571
# Test set results: loss= 1.8449 accuracy= 0.4930
# Train set results: loss= 1.8584 accuracy= 0.6857
# Test set results: loss= 1.9094 accuracy= 0.6240
# Train set results: loss= 1.8055 accuracy= 0.7143
# Test set results: loss= 1.8862 accuracy= 0.5780
# Train set results: loss= 1.4215 accuracy= 0.6500
# Test set results: loss= 1.7332 accuracy= 0.5170
# Train set results: loss= 1.6887 accuracy= 0.6357
# Test set results: loss= 1.8538 accuracy= 0.5080
# Train set results: loss= 1.6411 accuracy= 0.6643
# Test set results: loss= 1.8296 accuracy= 0.4960
# Train set results: loss= 1.6088 accuracy= 0.6286
# Test set results: loss= 1.8165 accuracy= 0.5540
# Train set results: loss= 1.3566 accuracy= 0.6143
# Test set results: loss= 1.7123 accuracy= 0.4920
# Train set results: loss= 1.5038 accuracy= 0.5929
# Test set results: loss= 1.7778 accuracy= 0.5030
# success
# Train set results: loss= 1.8289 accuracy= 0.7500
# Test set results: loss= 1.8982 accuracy= 0.6630
# success
# Train set results: loss= 1.4686 accuracy= 0.7429
# Test set results: loss= 1.7521 accuracy= 0.6030
# success
# Train set results: loss= 1.8523 accuracy= 0.7643
# Test set results: loss= 1.9075 accuracy= 0.6070
# success
# Train set results: loss= 1.7749 accuracy= 0.7571
# Test set results: loss= 1.8804 accuracy= 0.6340
# success
# Train set results: loss= 1.4304 accuracy= 0.7429
# Test set results: loss= 1.7366 accuracy= 0.5770
# success
# Train set results: loss= 1.9179 accuracy= 0.7857
# Test set results: loss= 1.9334 accuracy= 0.6120
# success
# Train set results: loss= 1.3172 accuracy= 0.7357
# Test set results: loss= 1.6840 accuracy= 0.5770
# success
# Train set results: loss= 1.4681 accuracy= 0.7214
# Test set results: loss= 1.7515 accuracy= 0.6040
# success
# Train set results: loss= 1.6531 accuracy= 0.7357
# Test set results: loss= 1.8268 accuracy= 0.6490
# success
# Train set results: loss= 1.8223 accuracy= 0.7214
# Test set results: loss= 1.8984 accuracy= 0.6330
# success
# Train set results: loss= 1.6109 accuracy= 0.7571
# Test set results: loss= 1.8120 accuracy= 0.6050
# success
# Train set results: loss= 1.5257 accuracy= 0.7429
# Test set results: loss= 1.7818 accuracy= 0.5840
# success
# Train set results: loss= 1.8164 accuracy= 0.7286
# Test set results: loss= 1.8914 accuracy= 0.6660
# success
# Train set results: loss= 1.4290 accuracy= 0.7571
# Test set results: loss= 1.7251 accuracy= 0.6140
# success
# Train set results: loss= 1.2361 accuracy= 0.7357
# Test set results: loss= 1.6444 accuracy= 0.5750
# success
# Train set results: loss= 1.6886 accuracy= 0.7500
# Test set results: loss= 1.8448 accuracy= 0.6120
# Train set results: loss= 1.6041 accuracy= 0.7429
# Test set results: loss= 1.8140 accuracy= 0.6030
# Train set results: loss= 1.5497 accuracy= 0.7357
# Test set results: loss= 1.7886 accuracy= 0.6140
# Train set results: loss= 1.4330 accuracy= 0.7286
# Test set results: loss= 1.7325 accuracy= 0.6210
# Train set results: loss= 1.5293 accuracy= 0.7429
# Test set results: loss= 1.7838 accuracy= 0.5960
# Train set results: loss= 1.6987 accuracy= 0.7500
# Test set results: loss= 1.8507 accuracy= 0.5950
# Train set results: loss= 1.7414 accuracy= 0.7643
# Test set results: loss= 1.8593 accuracy= 0.6270
# Train set results: loss= 1.4945 accuracy= 0.7357
# Test set results: loss= 1.7671 accuracy= 0.5900
# Train set results: loss= 1.6999 accuracy= 0.7571
# Test set results: loss= 1.8456 accuracy= 0.6590
# Train set results: loss= 1.7812 accuracy= 0.7286
# Test set results: loss= 1.8789 accuracy= 0.6380
# Train set results: loss= 1.8110 accuracy= 0.7214
# Test set results: loss= 1.8951 accuracy= 0.6230
# Train set results: loss= 1.5347 accuracy= 0.7571
# Test set results: loss= 1.7795 accuracy= 0.6270
# Train set results: loss= 1.8506 accuracy= 0.7500
# Test set results: loss= 1.9036 accuracy= 0.6460
# Train set results: loss= 1.6852 accuracy= 0.7429
# Test set results: loss= 1.8483 accuracy= 0.6030
# Train set results: loss= 1.6842 accuracy= 0.7500
# Test set results: loss= 1.8421 accuracy= 0.6290
# success
# Train set results: loss= 1.7796 accuracy= 0.7857
# Test set results: loss= 1.8810 accuracy= 0.6430
# success
# Train set results: loss= 1.6507 accuracy= 0.8143
# Test set results: loss= 1.8174 accuracy= 0.6800
# success
# Train set results: loss= 1.8510 accuracy= 0.7714
# Test set results: loss= 1.9054 accuracy= 0.6670
# success
# Train set results: loss= 1.7368 accuracy= 0.7857
# Test set results: loss= 1.8609 accuracy= 0.6800
# success
# Train set results: loss= 1.5629 accuracy= 0.7857
# Test set results: loss= 1.7873 accuracy= 0.6570
# success
# Train set results: loss= 1.5287 accuracy= 0.7857
# Test set results: loss= 1.7779 accuracy= 0.6670
# success
# Train set results: loss= 1.7043 accuracy= 0.7714
# Test set results: loss= 1.8503 accuracy= 0.6420
# success
# Train set results: loss= 1.6078 accuracy= 0.7857
# Test set results: loss= 1.8049 accuracy= 0.6820
# success
# Train set results: loss= 1.8166 accuracy= 0.7714
# Test set results: loss= 1.8903 accuracy= 0.6930
# success
# Train set results: loss= 1.7877 accuracy= 0.7857
# Test set results: loss= 1.8790 accuracy= 0.7140
# success
# Train set results: loss= 1.7878 accuracy= 0.7857
# Test set results: loss= 1.8843 accuracy= 0.6250
# success
# Train set results: loss= 1.6997 accuracy= 0.8000
# Test set results: loss= 1.8378 accuracy= 0.6810
# success
# Train set results: loss= 1.5955 accuracy= 0.7643
# Test set results: loss= 1.7959 accuracy= 0.6850
# success
# Train set results: loss= 1.7035 accuracy= 0.7857
# Test set results: loss= 1.8382 accuracy= 0.7110
# success
# Train set results: loss= 1.7607 accuracy= 0.7786
# Test set results: loss= 1.8693 accuracy= 0.6840
# success
# Train set results: loss= 1.7912 accuracy= 0.8286
# Test set results: loss= 1.8872 accuracy= 0.6620
# Train set results: loss= 1.3993 accuracy= 0.8000
# Test set results: loss= 1.7076 accuracy= 0.6410
# Train set results: loss= 1.2368 accuracy= 0.7857
# Test set results: loss= 1.6138 accuracy= 0.6710
# Train set results: loss= 1.8009 accuracy= 0.7643
# Test set results: loss= 1.8891 accuracy= 0.6720
# Train set results: loss= 1.4935 accuracy= 0.7643
# Test set results: loss= 1.7627 accuracy= 0.6360
# Train set results: loss= 1.8028 accuracy= 0.7714
# Test set results: loss= 1.8816 accuracy= 0.7080
# Train set results: loss= 1.6860 accuracy= 0.7929
# Test set results: loss= 1.8381 accuracy= 0.6840
# Train set results: loss= 1.3891 accuracy= 0.8071
# Test set results: loss= 1.7065 accuracy= 0.6630
# Train set results: loss= 1.7258 accuracy= 0.7786
# Test set results: loss= 1.8560 accuracy= 0.6880
# Train set results: loss= 1.6045 accuracy= 0.8143
# Test set results: loss= 1.7995 accuracy= 0.6960
# Train set results: loss= 1.7316 accuracy= 0.7857
# Test set results: loss= 1.8520 accuracy= 0.6960
# Train set results: loss= 1.7573 accuracy= 0.8143
# Test set results: loss= 1.8607 accuracy= 0.7140
# Train set results: loss= 1.4845 accuracy= 0.7929
# Test set results: loss= 1.7528 accuracy= 0.6590
# Train set results: loss= 1.3378 accuracy= 0.8000
# Test set results: loss= 1.6776 accuracy= 0.6320
# Train set results: loss= 1.5797 accuracy= 0.8000
# Test set results: loss= 1.7966 accuracy= 0.6580
# success
# Train set results: loss= 1.7183 accuracy= 0.8143
# Test set results: loss= 1.8485 accuracy= 0.7180
# success
# Train set results: loss= 1.7277 accuracy= 0.8143
# Test set results: loss= 1.8504 accuracy= 0.7030
# success
# Train set results: loss= 1.7060 accuracy= 0.8286
# Test set results: loss= 1.8501 accuracy= 0.6650
# success
# Train set results: loss= 1.4287 accuracy= 0.8429
# Test set results: loss= 1.7190 accuracy= 0.6670
# success
# Train set results: loss= 1.7541 accuracy= 0.8071
# Test set results: loss= 1.8630 accuracy= 0.6700
# success
# Train set results: loss= 1.7895 accuracy= 0.8214
# Test set results: loss= 1.8824 accuracy= 0.7050
# success
# Train set results: loss= 1.7819 accuracy= 0.8357
# Test set results: loss= 1.8721 accuracy= 0.7320
# success
# Train set results: loss= 1.8445 accuracy= 0.8357
# Test set results: loss= 1.9031 accuracy= 0.7040
# success
# Train set results: loss= 1.3027 accuracy= 0.8214
# Test set results: loss= 1.6603 accuracy= 0.6440
# success
# Train set results: loss= 1.5722 accuracy= 0.8143
# Test set results: loss= 1.7815 accuracy= 0.7190
# success
# Train set results: loss= 1.6379 accuracy= 0.8357
# Test set results: loss= 1.8168 accuracy= 0.7100
# success
# Train set results: loss= 1.7885 accuracy= 0.8286
# Test set results: loss= 1.8773 accuracy= 0.7130
# success
# Train set results: loss= 1.7492 accuracy= 0.8143
# Test set results: loss= 1.8595 accuracy= 0.7080
# success
# Train set results: loss= 1.6515 accuracy= 0.8214
# Test set results: loss= 1.8150 accuracy= 0.7120
# success
# Train set results: loss= 1.8038 accuracy= 0.8286
# Test set results: loss= 1.8825 accuracy= 0.7350
# success
# Train set results: loss= 1.8492 accuracy= 0.8286
# Test set results: loss= 1.9025 accuracy= 0.7200
# Train set results: loss= 1.7168 accuracy= 0.8143
# Test set results: loss= 1.8492 accuracy= 0.7210
# Train set results: loss= 1.7394 accuracy= 0.8143
# Test set results: loss= 1.8515 accuracy= 0.7250
# Train set results: loss= 1.7900 accuracy= 0.8357
# Test set results: loss= 1.8746 accuracy= 0.7440
# Train set results: loss= 1.5927 accuracy= 0.8286
# Test set results: loss= 1.7998 accuracy= 0.6930
# Train set results: loss= 1.5102 accuracy= 0.8357
# Test set results: loss= 1.7533 accuracy= 0.7020
# Train set results: loss= 1.4209 accuracy= 0.8286
# Test set results: loss= 1.7157 accuracy= 0.6740
# Train set results: loss= 1.7903 accuracy= 0.7929
# ...
# Test set results: loss= 1.7847 accuracy= 0.7900
# Train set results: loss= 1.3695 accuracy= 0.9500
# Test set results: loss= 1.6728 accuracy= 0.7900
# Train set results: loss= 0.7684 accuracy= 0.9429
# Test set results: loss= 1.3084 accuracy= 0.8020
# Train set results: loss= 1.7470 accuracy= 0.9357
# Test set results: loss= 1.8502 accuracy= 0.7770
# success
# Train set results: loss= 1.7693 accuracy= 0.9571
# Test set results: loss= 1.8646 accuracy= 0.8140
# success
# Train set results: loss= 1.4170 accuracy= 0.9571
# Test set results: loss= 1.6999 accuracy= 0.7850
# success
# Train set results: loss= 0.6486 accuracy= 0.9357
# Test set results: loss= 1.2182 accuracy= 0.7930
# success
# Train set results: loss= 1.6720 accuracy= 0.9500
# Test set results: loss= 1.8151 accuracy= 0.8180
# success
# Train set results: loss= 1.3449 accuracy= 0.9500
# Test set results: loss= 1.6657 accuracy= 0.7890
# success
# Train set results: loss= 1.0336 accuracy= 0.9500
# Test set results: loss= 1.4922 accuracy= 0.7910
# success
# Train set results: loss= 1.3606 accuracy= 0.9500
# Test set results: loss= 1.6646 accuracy= 0.7930
# success
# Train set results: loss= 0.5973 accuracy= 0.9357
# Test set results: loss= 1.1444 accuracy= 0.8040
# success
# Train set results: loss= 1.8503 accuracy= 0.9286
# Test set results: loss= 1.8986 accuracy= 0.7970
# success
# Train set results: loss= 1.4015 accuracy= 0.9500
# Test set results: loss= 1.6894 accuracy= 0.7980
# success
# Train set results: loss= 0.9009 accuracy= 0.9429
# Test set results: loss= 1.4044 accuracy= 0.7920
# success
# Train set results: loss= 0.5448 accuracy= 0.9214
# Test set results: loss= 1.0902 accuracy= 0.8030
# success
# Train set results: loss= 1.8511 accuracy= 0.9571
# Test set results: loss= 1.9031 accuracy= 0.7980
# success
# Train set results: loss= 1.5729 accuracy= 0.9429
# Test set results: loss= 1.7670 accuracy= 0.8010
# success
# Train set results: loss= 0.9811 accuracy= 0.9429
# Test set results: loss= 1.4631 accuracy= 0.7770
# success
# Train set results: loss= 0.6548 accuracy= 0.9429
# Test set results: loss= 1.2349 accuracy= 0.7890
# Train set results: loss= 1.3394 accuracy= 0.9429
# Test set results: loss= 1.6665 accuracy= 0.7790
# Train set results: loss= 1.3280 accuracy= 0.9500
# Test set results: loss= 1.6521 accuracy= 0.8060
# Train set results: loss= 1.8562 accuracy= 0.9500
# Test set results: loss= 1.9028 accuracy= 0.7990
# Train set results: loss= 1.5791 accuracy= 0.9571
# Test set results: loss= 1.7828 accuracy= 0.7820
# Train set results: loss= 0.5472 accuracy= 0.9214
# Test set results: loss= 1.0907 accuracy= 0.8010
# Train set results: loss= 1.4151 accuracy= 0.9500
# Test set results: loss= 1.6971 accuracy= 0.7930
# Train set results: loss= 1.4406 accuracy= 0.9500
# Test set results: loss= 1.7153 accuracy= 0.7860
# Train set results: loss= 1.6441 accuracy= 0.9571
# Test set results: loss= 1.8051 accuracy= 0.7940
# Train set results: loss= 1.5759 accuracy= 0.9500
# Test set results: loss= 1.7735 accuracy= 0.7900
# Train set results: loss= 1.7516 accuracy= 0.9214
# Test set results: loss= 1.8561 accuracy= 0.7780
# Train set results: loss= 1.3701 accuracy= 0.9500
# Test set results: loss= 1.6713 accuracy= 0.7920
# Train set results: loss= 1.7396 accuracy= 0.9500
# Test set results: loss= 1.8489 accuracy= 0.8240
# Train set results: loss= 1.6256 accuracy= 0.9429
# Test set results: loss= 1.7992 accuracy= 0.8030
# Train set results: loss= 1.5494 accuracy= 0.9500
# Test set results: loss= 1.7587 accuracy= 0.8030
# success
# Train set results: loss= 0.9300 accuracy= 0.9429
# Test set results: loss= 1.4291 accuracy= 0.7990
# success
# Train set results: loss= 1.7192 accuracy= 0.9571
# Test set results: loss= 1.8440 accuracy= 0.7970
# success
# Train set results: loss= 0.6372 accuracy= 0.9429
# Test set results: loss= 1.2017 accuracy= 0.7960
# success
# Train set results: loss= 0.5797 accuracy= 0.9429
# Test set results: loss= 1.1277 accuracy= 0.8030
# success
# Train set results: loss= 1.2629 accuracy= 0.9429
# Test set results: loss= 1.6218 accuracy= 0.7910
# success
# Train set results: loss= 1.4791 accuracy= 0.9571
# Test set results: loss= 1.7305 accuracy= 0.7990
# success
# Train set results: loss= 1.8306 accuracy= 0.9571
# Test set results: loss= 1.8913 accuracy= 0.7910
# success
# Train set results: loss= 0.9501 accuracy= 0.9429
# Test set results: loss= 1.4503 accuracy= 0.7770
# success
# Train set results: loss= 0.6634 accuracy= 0.9429
# Test set results: loss= 1.2328 accuracy= 0.7890
# success
# Train set results: loss= 1.2685 accuracy= 0.9429
# Test set results: loss= 1.6205 accuracy= 0.7920
# success
# Train set results: loss= 1.3914 accuracy= 0.9429
# Test set results: loss= 1.6944 accuracy= 0.7820
# success
# Train set results: loss= 1.4431 accuracy= 0.9429
# Test set results: loss= 1.7153 accuracy= 0.7810
# success
# Train set results: loss= 1.7534 accuracy= 0.9571
# Test set results: loss= 1.8584 accuracy= 0.8110
# success
# Train set results: loss= 1.3881 accuracy= 0.9429
# Test set results: loss= 1.6904 accuracy= 0.7930
# success
# Train set results: loss= 1.6829 accuracy= 0.9643
# Test set results: loss= 1.8248 accuracy= 0.8070
# success
# Train set results: loss= 1.0774 accuracy= 0.9429
# Test set results: loss= 1.5204 accuracy= 0.7850
# Train set results: loss= 1.7593 accuracy= 0.9357
# Test set results: loss= 1.8587 accuracy= 0.7870
# Train set results: loss= 0.9016 accuracy= 0.9429
# Test set results: loss= 1.4111 accuracy= 0.7990
# Train set results: loss= 1.5917 accuracy= 0.9500
# Test set results: loss= 1.7835 accuracy= 0.8030
# Train set results: loss= 1.3214 accuracy= 0.9500
# Test set results: loss= 1.6464 accuracy= 0.8040
# Train set results: loss= 1.8318 accuracy= 0.9500
# Test set results: loss= 1.8944 accuracy= 0.7860
# Train set results: loss= 1.8384 accuracy= 0.9429
# Test set results: loss= 1.8951 accuracy= 0.8210
# Train set results: loss= 0.7765 accuracy= 0.9429
# Test set results: loss= 1.3193 accuracy= 0.7970
# Train set results: loss= 1.1481 accuracy= 0.9429
# Test set results: loss= 1.5580 accuracy= 0.7850
# Train set results: loss= 1.7346 accuracy= 0.9500
# Test set results: loss= 1.8486 accuracy= 0.8060
# Train set results: loss= 1.6443 accuracy= 0.9500
# Test set results: loss= 1.8082 accuracy= 0.7920
# Train set results: loss= 0.5603 accuracy= 0.9286
# Test set results: loss= 1.1198 accuracy= 0.7950
# Train set results: loss= 1.3002 accuracy= 0.9429
# Test set results: loss= 1.6366 accuracy= 0.8040
# Train set results: loss= 1.7261 accuracy= 0.9429
# Test set results: loss= 1.8430 accuracy= 0.8140
# Train set results: loss= 0.5299 accuracy= 0.9214
# Test set results: loss= 1.0705 accuracy= 0.7940
# success
# Train set results: loss= 0.9764 accuracy= 0.9571
# Test set results: loss= 1.4568 accuracy= 0.7920
# success
# Train set results: loss= 1.6394 accuracy= 0.9571
# Test set results: loss= 1.8057 accuracy= 0.7890
# success
# Train set results: loss= 1.5158 accuracy= 0.9500
# Test set results: loss= 1.7469 accuracy= 0.7950
# success
# Train set results: loss= 1.7451 accuracy= 0.9500
# Test set results: loss= 1.8540 accuracy= 0.7990
# success
# Train set results: loss= 1.1302 accuracy= 0.9571
# Test set results: loss= 1.5490 accuracy= 0.7910
# success
# Train set results: loss= 1.3932 accuracy= 0.9429
# Test set results: loss= 1.6915 accuracy= 0.7960
# success
# Train set results: loss= 1.4698 accuracy= 0.9500
# Test set results: loss= 1.7245 accuracy= 0.7830
# success
# Train set results: loss= 1.6354 accuracy= 0.9500
# Test set results: loss= 1.8047 accuracy= 0.7920
# success
# Train set results: loss= 0.6761 accuracy= 0.9429
# Test set results: loss= 1.2480 accuracy= 0.7890
# success
# Train set results: loss= 1.1691 accuracy= 0.9429
# Test set results: loss= 1.5751 accuracy= 0.7760
# success
# Train set results: loss= 1.3792 accuracy= 0.9429
# Test set results: loss= 1.6875 accuracy= 0.7760
# success
# Train set results: loss= 1.6149 accuracy= 0.9500
# Test set results: loss= 1.7945 accuracy= 0.8090
# success
# Train set results: loss= 1.5650 accuracy= 0.9500
# Test set results: loss= 1.7627 accuracy= 0.7990
# success
# Train set results: loss= 0.7858 accuracy= 0.9429
# Test set results: loss= 1.3294 accuracy= 0.7870
# success
# Train set results: loss= 0.8759 accuracy= 0.9429
# Test set results: loss= 1.3899 accuracy= 0.7850
# success
# Train set results: loss= 0.6699 accuracy= 0.9429
# Test set results: loss= 1.2342 accuracy= 0.7990
# Train set results: loss= 0.6281 accuracy= 0.9357
# Test set results: loss= 1.2025 accuracy= 0.7770
# Train set results: loss= 1.7959 accuracy= 0.9429
# Test set results: loss= 1.8779 accuracy= 0.7770
# Train set results: loss= 1.4426 accuracy= 0.9429
# Test set results: loss= 1.7134 accuracy= 0.7730
# Train set results: loss= 1.7176 accuracy= 0.9500
# Test set results: loss= 1.8461 accuracy= 0.7690
# Train set results: loss= 1.7790 accuracy= 0.9357
# Test set results: loss= 1.8684 accuracy= 0.7970
# Train set results: loss= 0.7446 accuracy= 0.9429
# Test set results: loss= 1.2973 accuracy= 0.7980
# Train set results: loss= 1.7728 accuracy= 0.9571
# Test set results: loss= 1.8675 accuracy= 0.8050
# Train set results: loss= 0.9469 accuracy= 0.9500
# Test set results: loss= 1.4388 accuracy= 0.7900
# Train set results: loss= 1.7899 accuracy= 0.9500
# Test set results: loss= 1.8754 accuracy= 0.7890
# Train set results: loss= 1.5931 accuracy= 0.9500
# Test set results: loss= 1.7896 accuracy= 0.7840
# Train set results: loss= 0.7970 accuracy= 0.9357
# Test set results: loss= 1.3390 accuracy= 0.7940
# Train set results: loss= 0.5176 accuracy= 0.9071
# Test set results: loss= 1.0063 accuracy= 0.7980
# Train set results: loss= 1.4410 accuracy= 0.9500
# Test set results: loss= 1.7152 accuracy= 0.7860
# Train set results: loss= 1.2244 accuracy= 0.9500
# Test set results: loss= 1.5968 accuracy= 0.8000
# success
# Train set results: loss= 0.6713 accuracy= 0.9429
# Test set results: loss= 1.2215 accuracy= 0.8070
# success
# Train set results: loss= 0.5609 accuracy= 0.9286
# Test set results: loss= 1.1192 accuracy= 0.7980
# success
# Train set results: loss= 1.2488 accuracy= 0.9429
# Test set results: loss= 1.6172 accuracy= 0.7920
# success
# Train set results: loss= 0.6764 accuracy= 0.9429
# Test set results: loss= 1.2412 accuracy= 0.7930
# success
# Train set results: loss= 1.3852 accuracy= 0.9500
# Test set results: loss= 1.6870 accuracy= 0.7880
# success
# Train set results: loss= 0.8982 accuracy= 0.9429
# Test set results: loss= 1.4026 accuracy= 0.8000
# success
# Train set results: loss= 1.6367 accuracy= 0.9429
# Test set results: loss= 1.8053 accuracy= 0.7900
# success
# Train set results: loss= 0.5629 accuracy= 0.9357
# Test set results: loss= 1.1233 accuracy= 0.7880
# success
# Train set results: loss= 1.7911 accuracy= 0.9500
# Test set results: loss= 1.8749 accuracy= 0.8100
# success
# Train set results: loss= 1.4219 accuracy= 0.9429
# Test set results: loss= 1.6900 accuracy= 0.8090
# success
# Train set results: loss= 1.7786 accuracy= 0.9357
# Test set results: loss= 1.8670 accuracy= 0.7860
# success
# Train set results: loss= 0.8159 accuracy= 0.9429
# Test set results: loss= 1.3408 accuracy= 0.7960
# success
# Train set results: loss= 0.8919 accuracy= 0.9429
# Test set results: loss= 1.4103 accuracy= 0.7890
# success
# Train set results: loss= 0.7660 accuracy= 0.9429
# Test set results: loss= 1.3210 accuracy= 0.7930
# success
# Train set results: loss= 1.6613 accuracy= 0.9429
# Test set results: loss= 1.8138 accuracy= 0.8130
# success
# Train set results: loss= 1.2546 accuracy= 0.9500
# Test set results: loss= 1.6199 accuracy= 0.7910
# Train set results: loss= 1.4689 accuracy= 0.9571
# Test set results: loss= 1.7211 accuracy= 0.8070
# Train set results: loss= 1.6437 accuracy= 0.9571
# Test set results: loss= 1.8129 accuracy= 0.7900
# Train set results: loss= 1.7601 accuracy= 0.9357
# Test set results: loss= 1.8617 accuracy= 0.7840
# Train set results: loss= 1.6063 accuracy= 0.9429
# Test set results: loss= 1.7955 accuracy= 0.7880
# Train set results: loss= 1.7668 accuracy= 0.9429
# Test set results: loss= 1.8638 accuracy= 0.7860
# Train set results: loss= 1.4631 accuracy= 0.9500
# Test set results: loss= 1.7260 accuracy= 0.7950
# Train set results: loss= 1.5718 accuracy= 0.9500
# Test set results: loss= 1.7712 accuracy= 0.8060
# Train set results: loss= 0.9340 accuracy= 0.9500
# Test set results: loss= 1.4221 accuracy= 0.7990
# Train set results: loss= 1.6877 accuracy= 0.9500
# Test set results: loss= 1.8239 accuracy= 0.8030
# Train set results: loss= 1.5409 accuracy= 0.9643
# Test set results: loss= 1.7614 accuracy= 0.7930
# Train set results: loss= 1.7581 accuracy= 0.9500
# Test set results: loss= 1.8612 accuracy= 0.8030
# Train set results: loss= 1.3381 accuracy= 0.9571
# Test set results: loss= 1.6561 accuracy= 0.7990
# Train set results: loss= 1.0573 accuracy= 0.9429
# Test set results: loss= 1.5061 accuracy= 0.7940
# Train set results: loss= 1.7951 accuracy= 0.9429
# Test set results: loss= 1.8770 accuracy= 0.7930
# success
# Train set results: loss= 1.7122 accuracy= 0.9500
# Test set results: loss= 1.8383 accuracy= 0.8020
# success
# Train set results: loss= 0.5441 accuracy= 0.9286
# Test set results: loss= 1.1037 accuracy= 0.7900
# success
# Train set results: loss= 0.9074 accuracy= 0.9500
# Test set results: loss= 1.4095 accuracy= 0.7940
# success
# Train set results: loss= 0.8215 accuracy= 0.9429
# Test set results: loss= 1.3588 accuracy= 0.8040
# success
# Train set results: loss= 1.6661 accuracy= 0.9500
# Test set results: loss= 1.8193 accuracy= 0.7950
# success
# Train set results: loss= 1.6608 accuracy= 0.9429
# Test set results: loss= 1.8123 accuracy= 0.8230
# success
# Train set results: loss= 1.2173 accuracy= 0.9500
# Test set results: loss= 1.5894 accuracy= 0.8080
# success
# Train set results: loss= 1.4352 accuracy= 0.9500
# Test set results: loss= 1.7083 accuracy= 0.7980
# success
# Train set results: loss= 0.8157 accuracy= 0.9429
# Test set results: loss= 1.3570 accuracy= 0.7820
# success
# Train set results: loss= 0.7003 accuracy= 0.9429
# Test set results: loss= 1.2473 accuracy= 0.7950
# success
# Train set results: loss= 1.0131 accuracy= 0.9429
# Test set results: loss= 1.4708 accuracy= 0.7900
# success
# Train set results: loss= 0.7413 accuracy= 0.9429
# Test set results: loss= 1.2900 accuracy= 0.8040
# success
# Train set results: loss= 1.7382 accuracy= 0.9643
# Test set results: loss= 1.8497 accuracy= 0.8070
# success
# Train set results: loss= 1.7363 accuracy= 0.9357
# Test set results: loss= 1.8449 accuracy= 0.8070
# success
# Train set results: loss= 1.5275 accuracy= 0.9571
# Test set results: loss= 1.7530 accuracy= 0.8010
# success
# Train set results: loss= 0.6899 accuracy= 0.9429
# Test set results: loss= 1.2465 accuracy= 0.7960
# Train set results: loss= 1.6524 accuracy= 0.9429
# Test set results: loss= 1.8101 accuracy= 0.8060
# Train set results: loss= 1.3782 accuracy= 0.9500
# Test set results: loss= 1.6815 accuracy= 0.7900
# Train set results: loss= 1.6706 accuracy= 0.9429
# Test set results: loss= 1.8247 accuracy= 0.7850
# Train set results: loss= 1.2360 accuracy= 0.9500
# Test set results: loss= 1.6102 accuracy= 0.7880
# Train set results: loss= 0.8436 accuracy= 0.9429
# Test set results: loss= 1.3703 accuracy= 0.7930
# Train set results: loss= 0.5373 accuracy= 0.9214
# Test set results: loss= 1.0822 accuracy= 0.7910
# Train set results: loss= 0.8968 accuracy= 0.9357
# Test set results: loss= 1.4086 accuracy= 0.7920
# Train set results: loss= 1.6935 accuracy= 0.9500
# Test set results: loss= 1.8301 accuracy= 0.8060
# Train set results: loss= 1.7223 accuracy= 0.9571
# Test set results: loss= 1.8439 accuracy= 0.8090
# Train set results: loss= 1.2598 accuracy= 0.9500
# Test set results: loss= 1.6153 accuracy= 0.7950
# Train set results: loss= 1.8940 accuracy= 0.9429
# Test set results: loss= 1.9231 accuracy= 0.8020
# Train set results: loss= 1.2771 accuracy= 0.9500
# Test set results: loss= 1.6331 accuracy= 0.7870
# Train set results: loss= 1.7685 accuracy= 0.9500
# Test set results: loss= 1.8652 accuracy= 0.8140
# Train set results: loss= 0.6933 accuracy= 0.9429
# Test set results: loss= 1.2581 accuracy= 0.7950
# Epoch 600, loss_avg: 0.2000507407147162
# Train set results: loss= 1.7924 accuracy= 0.9714
# Test set results: loss= 1.8779 accuracy= 0.7780
# Train set results: loss= 1.2988 accuracy= 0.9500
# Test set results: loss= 1.6346 accuracy= 0.8050
# Train set results: loss= 0.7532 accuracy= 0.9429
# Test set results: loss= 1.3013 accuracy= 0.7920
# Train/Test Mean Accuracy: [array([0.9547619 , 0.79166667]), array([0.01214052, 0.01102522])]

# %%
args.reduction_rate = 0.5
agent = GCond(data, args, device='cuda:0')

agent.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 args.reduction_rate = 0.5
#       2 agent = GCond(data, args, device='cuda:0')
#       4 agent.train()
#
# NameError: name 'args' is not defined

# %%
args.reduction_rate = 1
agent = GCond(data, args, device='cuda:0')

agent.train()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 args.reduction_rate = 1
#       2 agent = GCond(data, args, device='cuda:0')
#       4 agent.train()
#
# NameError: name 'args' is not defined

# %%
# 81.2±0.2
